# %%
import json

# %%
with open('./openimages_v6_dict_indices_per_image.json', 'r') as f:
    dict_test = json.load(f)

# %%
for image_name in dict_test:
    print(len(dict_test[image_name]))
# Out:
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# ...

# %%
len(dict_test)
# Out:
# 260

# %%
dict_test
# Out:
# {'10014304546_812290b498_o.jpg': [42,
#   226,
#   23,
#   96,
#   167,
#   184,
#   217,
#   129,
#   47,
#   5,
#   91,
#   100,
#   116,
#   78,
#   52,
#   20,
#   130,
#   192,
#   48,
#   50,
#   19,
#   51,
#   183,
#   133,
#   176,
#   30,
#   68,
#   238,
#   212,
#   103,
#   139,
#   89,
#   43,
#   58,
#   138,
#   141,
#   71,
#   125,
#   121,
#   22,
#   189,
#   147,
#   14,
#   13,
#   253,
#   3,
#   107,
#   218,
#   156,
#   208,
#   236,
#   35,
#   18,
#   191,
#   120,
#   17,
#   75,
#   101,
#   197,
#   67,
#   26,
#   69,
#   90,
#   165,
#   213,
#   11,
#   31,
#   112,
#   246,
#   227,
#   86,
#   155,
#   144,
#   61,
#   83,
#   166,
#   249,
#   123,
#   169,
#   108,
#   59,
#   225,
#   142,
#   104,
#   98,
#   137,
#   134,
#   127,
#   1,
#   219,
#   234,
#   92,
#   252,
#   99,
#   243,
#   10,
#   44,
#   228,
#   37,
#   135,
#   64,
#   34,
#   240,
#   211,
#   200,
#   24,
#   250,
#   55,
#   132,
#   193,
#   117,
#   182,
#   115,
# ...
