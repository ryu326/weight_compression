# %%
import matplotlib.pyplot as plt
import json

import json
import matplotlib.pyplot as plt
import os
import glob

# 디렉토리 경로 설정
# directory = '/home/jgryu/Weight_compression/RD-sandwich/checkpoints/gemma_2b_attn_d=256_b=512'  # 원하는 디렉토리 경로로 변경
directory = '/home/jgryu/Weight_compression/RD-sandwich/checkpoints/llama-2-7b_attn_d=256_b=1024'  # 원하는 디렉토리 경로로 변경
directory = '/home/jgryu/Weight_compression/RD-sandwich/checkpoints/llama-2-7b_attn_d=32_b=1024'  # 원하는 디렉토리 경로로 변경
directory = '/home/jgryu/Weight_compression/RD-sandwich/checkpoints/llama-2-7b_attn_d=2048_b=1024'  # 원하는 디렉토리 경로로 변경
directory = '/home/jgryu/Weight_compression/RD-sandwich/checkpoints/llama-2-7b_attn_d=1024_b=1024'  # 원하는 디렉토리 경로로 변경
directory = '/home/jgryu/Weight_compression/RD-sandwich/checkpoints/llama-2-7b_attn_d=128_b=1024'  # 원하는 디렉토리 경로로 변경
units='2000_2000_2000'
units='1000_1000_1000'

file_list = glob.glob(f'{directory}/**/*.jsonl', recursive=True)

dirlist  = os.listdir(directory)
lmbdas = set([0])
for d in dirlist:
    if not 'lmbda=' in d:
        continue
    start = d.find('lmbda=') + len('lmbda=')
    end = d.find('-encoder', start)
    lmbda_value = float(d[start:end])
    # print(lmbda_value)
    lmbdas.add(lmbda_value)

# print(lmbdas)
lmbdas = sorted(lmbdas)
# lmbdas = lmbdas[1:19]
print(lmbdas)
data_dict = {}

if 0 in lmbdas:
    for file_path in file_list:
        if (not f'lmbda' in file_path) and f'units={units}' in file_path:
            with open(file_path, 'r') as f:
                for line in f:
                    data_dict[0].append(json.loads(line))

for l in lmbdas: 
    data_dict[l] = []
for l in lmbdas:
    for file_path in file_list:
        if (f'lmbda={l}' in file_path) and f'units={units}'  in file_path:
            with open(file_path, 'r') as f:
                for line in f:
                    data_dict[l].append(json.loads(line))




def get_rate_mse(e, data):
    for entry in data:
        if entry['epoch'] == e:
            return entry['val_rate'], entry['val_mse'], entry['rate'], entry['mse']
    return None, None, None, None  # 해당 epoch이 없을 경우



# val_rate와 val_mse 데이터를 리스트로 추출
epoch = 19
# for epoch in range(10,11):
data = [get_rate_mse(epoch, data_dict[l]) for l in lmbdas]
# sorted_data = sorted(data, key=lambda x: x[1])

val_rate = [entry[0] for entry in data]
val_mse = [entry[1] for entry in data]
rate = [entry[2] for entry in data]
mse = [entry[3] for entry in data]

# 플롯 그리기
plt.figure(figsize=(8, 6))
plt.plot(val_mse, val_rate, marker='o', linestyle='-', label='val')
# plt.plot(mse, rate, marker='o', linestyle='-', label='train')

# 그래프 제목 및 레이블 설정
plt.title('Validation Rate vs. Validation MSE')
plt.xlabel('MSE')
plt.ylabel('Rate')
plt.legend()
# 그리드 추가
plt.grid(True)

# 그래프 보여주기
plt.show()
# Out:
# [0, 1e-20, 3e-20, 1e-19, 3e-19, 1e-18, 3e-18, 1e-17, 3e-17, 1e-16, 3e-16, 1e-15, 3e-15, 1e-14, 3e-14, 1e-13, 3e-13, 1e-12, 3e-12, 1e-11, 3e-11, 1e-10, 3e-10, 1e-09, 3e-09, 1e-08, 3e-08, 1e-07, 3e-07, 1e-06, 3e-06, 1e-05, 3e-05]

# %%
for i in range(len(lmbdas)):
    print(val_rate[i], val_mse[i], lmbdas[i])
    print(rate[i], mse[i], lmbdas[i])
# Out:
# None None 0
# None None 0
# 1.77011e-05 1.66284 1e-20
# 3.08483e-05 1.6627 1e-20
# 1.53354e-05 1.66286 3e-20
# 2.98905e-05 1.66271 3e-20
# 1.40135e-05 1.66285 1e-19
# 3.13089e-05 1.66271 1e-19
# 2.16126e-06 1.66282 3e-19
# 3.53454e-05 1.6627 3e-19
# 1.28661e-05 1.66281 1e-18
# 3.20931e-05 1.6627 1e-18
# 1.48126e-05 1.66283 3e-18
# 2.93784e-05 1.6627 3e-18
# 1.46206e-05 1.66287 1e-17
# 3.10142e-05 1.66271 1e-17
# 7.12752e-06 1.66284 3e-17
# 3.13451e-05 1.66271 3e-17
# 4.93884e-06 1.6628 1e-16
# 3.53014e-05 1.6627 1e-16
# 7.50765e-06 1.66283 3e-16
# 3.14819e-05 1.6627 3e-16
# 2.38952e-05 1.66285 1e-15
# 3.03837e-05 1.66271 1e-15
# 1.89944e-05 1.66287 3e-15
# 3.12051e-05 1.6627 3e-15
# 1.61377e-05 1.66281 1e-14
# 3.0828e-05 1.6627 1e-14
# -1.01328e-07 1.66281 3e-14
# 3.01753e-05 1.6627 3e-14
# 1.68523e-05 1.66277 1e-13
# 3.13389e-05 1.66262 1e-13
# 1.55756e-05 1.66226 3e-13
# 3.01901e-05 1.6621 3e-13
# 1.95302e-05 1.65643 1e-12
# 3.08962e-05 1.6562 1e-12
# 2.67655e-06 1.60709 3e-12
# 3.10376e-05 1.60694 3e-12
# 3.10908e-05 1.22142 1e-11
# 3.07324e-05 1.22127 1e-11
# 6.33851e-06 0.457491 3e-11
# 3.19081e-05 0.45748 3e-11
# 5.3373e-06 0.0618321 1e-10
# 3.08298e-05 0.0618033 1e-10
# 1.2114e-05 0.0411352 3e-10
# 3.02749e-05 0.0410872 3e-10
# 9.83626e-07 0.0395201 1e-09
# 3.05193e-05 0.0394837 1e-09
# 4.00089e-05 0.0323312 3e-09
# 3.14028e-05 0.0322818 3e-09
# 5.2768e-06 0.0173811 1e-08
# 3.00497e-05 0.0173624 1e-08
# 6.5887e-06 0.0079168 3e-08
# 2.97624e-05 0.00790976 3e-08
# 1.22866e-05 0.00311778 1e-07
# 3.15265e-05 0.00311618 1e-07
# 1.64194e-05 0.00143699 3e-07
# 2.93864e-05 0.00143616 3e-07
# 3.43555e-05 0.000668494 1e-06
# 3.08978e-05 0.000667836 1e-06
# 2.1503e-05 0.000445919 3e-06
# 3.15462e-05 0.000445521 3e-06
# 1.24331e-05 0.000415462 1e-05
# 3.08274e-05 0.000415107 1e-05
# 2.80595e-05 0.000411585 3e-05
# 3.14886e-05 0.000411239 3e-05

# %%
data_dict
# Out:
# {1e-20: [{'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 1.12019,
#    'val_loss': 0.837413,
#    'val_rate': 0.837413,
#    'val_mse': 1.1188},
#   {'epoch': 1,
#    'loss': 0.772437,
#    'rate': 0.772437,
#    'mse': 1.11801,
#    'val_loss': 0.644114,
#    'val_rate': 0.644114,
#    'val_mse': 1.11306},
#   {'epoch': 2,
#    'loss': 0.589583,
#    'rate': 0.589583,
#    'mse': 1.11475,
#    'val_loss': 0.489241,
#    'val_rate': 0.489241,
#    'val_mse': 1.11006},
#   {'epoch': 3,
#    'loss': 0.479839,
#    'rate': 0.479839,
#    'mse': 1.1121,
#    'val_loss': 0.488303,
#    'val_rate': 0.488303,
#    'val_mse': 1.1183},
#   {'epoch': 4,
#    'loss': 0.397094,
#    'rate': 0.397094,
#    'mse': 1.10967,
#    'val_loss': 0.355766,
#    'val_rate': 0.355766,
#    'val_mse': 1.10771},
#   {'epoch': 5,
#    'loss': 0.337412,
#    'rate': 0.337412,
#    'mse': 1.10767,
#    'val_loss': 0.301487,
#    'val_rate': 0.301487,
#    'val_mse': 1.1037},
#   {'epoch': 6,
#    'loss': 0.297406,
#    'rate': 0.297406,
#    'mse': 1.10576,
#    'val_loss': 0.279618,
#    'val_rate': 0.279618,
#    'val_mse': 1.10942},
#   {'epoch': 7,
#    'loss': 0.265559,
#    'rate': 0.265559,
#    'mse': 1.10424,
#    'val_loss': 0.254433,
#    'val_rate': 0.254433,
#    'val_mse': 1.10442},
#   {'epoch': 8,
#    'loss': 0.242236,
#    'rate': 0.242236,
#    'mse': 1.10272,
#    'val_loss': 0.224071,
#    'val_rate': 0.224071,
#    'val_mse': 1.10108},
#   {'epoch': 9,
#    'loss': 0.225857,
#    'rate': 0.225857,
#    'mse': 1.10128,
#    'val_loss': 0.221898,
#    'val_rate': 0.221898,
#    'val_mse': 1.1039},
#   {'epoch': 10,
#    'loss': 0.0480197,
#    'rate': 0.0480197,
#    'mse': 1.10075,
#    'val_loss': 0.0502059,
#    'val_rate': 0.0502059,
#    'val_mse': 1.10238},
#   {'epoch': 11,
#    'loss': 0.048033,
#    'rate': 0.048033,
#    'mse': 1.10064,
#    'val_loss': 0.0511773,
#    'val_rate': 0.0511773,
#    'val_mse': 1.10298},
#   {'epoch': 12,
#    'loss': 0.0479361,
#    'rate': 0.0479361,
#    'mse': 1.10048,
#    'val_loss': 0.0553761,
#    'val_rate': 0.0553761,
#    'val_mse': 1.10387},
#   {'epoch': 13,
#    'loss': 0.047506,
#    'rate': 0.047506,
#    'mse': 1.10058,
#    'val_loss': 0.0455886,
#    'val_rate': 0.0455886,
#    'val_mse': 1.10012},
#   {'epoch': 14,
#    'loss': 0.0476282,
#    'rate': 0.0476282,
#    'mse': 1.10043,
#    'val_loss': 0.0433093,
#    'val_rate': 0.0433093,
#    'val_mse': 1.10013},
#   {'epoch': 15,
#    'loss': 0.0111293,
#    'rate': 0.0111293,
#    'mse': 1.10046,
#    'val_loss': 0.0102024,
#    'val_rate': 0.0102024,
#    'val_mse': 1.10005},
#   {'epoch': 16,
#    'loss': 0.00983289,
#    'rate': 0.00983289,
#    'mse': 1.10044,
#    'val_loss': 0.00990026,
#    'val_rate': 0.00990026,
#    'val_mse': 1.10103},
#   {'epoch': 17,
#    'loss': 0.00991198,
#    'rate': 0.00991198,
#    'mse': 1.10049,
#    'val_loss': 0.0100878,
#    'val_rate': 0.0100878,
#    'val_mse': 1.10091},
#   {'epoch': 18,
#    'loss': 0.00341461,
#    'rate': 0.00341461,
#    'mse': 1.10044,
#    'val_loss': 0.00228278,
#    'val_rate': 0.00228278,
#    'val_mse': 1.10086},
#   {'epoch': 19,
#    'loss': 0.00223372,
#    'rate': 0.00223372,
#    'mse': 1.10041,
#    'val_loss': 0.00242227,
#    'val_rate': 0.00242227,
#    'val_mse': 1.10052}],
#  3e-20: [{'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 1.12019,
#    'val_loss': 0.837456,
#    'val_rate': 0.837456,
#    'val_mse': 1.11886},
#   {'epoch': 1,
#    'loss': 0.77247,
#    'rate': 0.77247,
#    'mse': 1.11801,
#    'val_loss': 0.644727,
#    'val_rate': 0.644727,
#    'val_mse': 1.11301},
#   {'epoch': 2,
#    'loss': 0.589445,
#    'rate': 0.589445,
#    'mse': 1.11475,
#    'val_loss': 0.487651,
#    'val_rate': 0.487651,
#    'val_mse': 1.11032},
#   {'epoch': 3,
#    'loss': 0.479879,
#    'rate': 0.479879,
#    'mse': 1.1121,
#    'val_loss': 0.491651,
#    'val_rate': 0.491651,
#    'val_mse': 1.11848},
#   {'epoch': 4,
#    'loss': 0.397147,
#    'rate': 0.397147,
#    'mse': 1.10967,
#    'val_loss': 0.355311,
#    'val_rate': 0.355311,
#    'val_mse': 1.10788},
#   {'epoch': 5,
#    'loss': 0.337467,
#    'rate': 0.337467,
#    'mse': 1.10767,
#    'val_loss': 0.304478,
#    'val_rate': 0.304478,
#    'val_mse': 1.10334},
#   {'epoch': 6,
#    'loss': 0.297273,
#    'rate': 0.297273,
#    'mse': 1.10576,
#    'val_loss': 0.278344,
#    'val_rate': 0.278344,
#    'val_mse': 1.10928},
#   {'epoch': 7,
#    'loss': 0.265506,
#    'rate': 0.265506,
#    'mse': 1.10424,
#    'val_loss': 0.255376,
#    'val_rate': 0.255376,
#    'val_mse': 1.1046},
#   {'epoch': 8,
#    'loss': 0.242263,
#    'rate': 0.242263,
#    'mse': 1.10271,
#    'val_loss': 0.224001,
#    'val_rate': 0.224001,
#    'val_mse': 1.10111},
#   {'epoch': 9,
#    'loss': 0.225766,
#    'rate': 0.225766,
#    'mse': 1.10128,
#    'val_loss': 0.224966,
#    'val_rate': 0.224966,
#    'val_mse': 1.10431},
#   {'epoch': 10,
#    'loss': 0.048009,
#    'rate': 0.048009,
#    'mse': 1.10075,
#    'val_loss': 0.0505257,
#    'val_rate': 0.0505257,
#    'val_mse': 1.10247},
#   {'epoch': 11,
#    'loss': 0.048022,
#    'rate': 0.048022,
#    'mse': 1.10064,
#    'val_loss': 0.0506658,
#    'val_rate': 0.0506658,
#    'val_mse': 1.10286},
#   {'epoch': 12,
#    'loss': 0.0479236,
#    'rate': 0.0479236,
#    'mse': 1.10048,
#    'val_loss': 0.0551354,
#    'val_rate': 0.0551354,
#    'val_mse': 1.10384},
#   {'epoch': 13,
#    'loss': 0.0474984,
#    'rate': 0.0474984,
#    'mse': 1.10058,
#    'val_loss': 0.0455984,
#    'val_rate': 0.0455984,
#    'val_mse': 1.10022},
#   {'epoch': 14,
#    'loss': 0.0476212,
#    'rate': 0.0476212,
#    'mse': 1.10043,
#    'val_loss': 0.0432384,
#    'val_rate': 0.0432384,
#    'val_mse': 1.10025},
#   {'epoch': 15,
#    'loss': 0.0111339,
#    'rate': 0.0111339,
#    'mse': 1.10046,
#    'val_loss': 0.0102302,
#    'val_rate': 0.0102302,
#    'val_mse': 1.10012},
#   {'epoch': 16,
#    'loss': 0.0098271,
#    'rate': 0.0098271,
#    'mse': 1.10044,
#    'val_loss': 0.0100189,
#    'val_rate': 0.0100189,
#    'val_mse': 1.1011},
#   {'epoch': 17,
#    'loss': 0.00990464,
#    'rate': 0.00990464,
#    'mse': 1.10049,
#    'val_loss': 0.0101208,
#    'val_rate': 0.0101208,
#    'val_mse': 1.10095},
#   {'epoch': 18,
#    'loss': 0.00342341,
#    'rate': 0.00342341,
#    'mse': 1.10044,
#    'val_loss': 0.00228747,
#    'val_rate': 0.00228747,
#    'val_mse': 1.10086},
#   {'epoch': 19,
#    'loss': 0.00224666,
#    'rate': 0.00224666,
#    'mse': 1.10041,
#    'val_loss': 0.00242356,
#    'val_rate': 0.00242356,
#    'val_mse': 1.10052}],
#  1e-19: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837366,
#    'val_rate': 0.837366,
#    'val_mse': 1.1188},
#   {'epoch': 1,
#    'loss': 0.772494,
#    'rate': 0.772494,
#    'mse': 1.11801,
#    'val_loss': 0.644924,
#    'val_rate': 0.644924,
#    'val_mse': 1.11298},
#   {'epoch': 2,
#    'loss': 0.589518,
#    'rate': 0.589518,
#    'mse': 1.11475,
#    'val_loss': 0.488877,
#    'val_rate': 0.488877,
#    'val_mse': 1.11012},
#   {'epoch': 3,
#    'loss': 0.479822,
#    'rate': 0.479822,
#    'mse': 1.1121,
#    'val_loss': 0.491455,
#    'val_rate': 0.491455,
#    'val_mse': 1.11847},
#   {'epoch': 4,
#    'loss': 0.397116,
#    'rate': 0.397116,
#    'mse': 1.10967,
#    'val_loss': 0.355628,
#    'val_rate': 0.355628,
#    'val_mse': 1.10776},
#   {'epoch': 5,
#    'loss': 0.337457,
#    'rate': 0.337457,
#    'mse': 1.10767,
#    'val_loss': 0.302246,
#    'val_rate': 0.302246,
#    'val_mse': 1.1036},
#   {'epoch': 6,
#    'loss': 0.297322,
#    'rate': 0.297322,
#    'mse': 1.10576,
#    'val_loss': 0.278817,
#    'val_rate': 0.278817,
#    'val_mse': 1.10933},
#   {'epoch': 7,
#    'loss': 0.265341,
#    'rate': 0.265341,
#    'mse': 1.10424,
#    'val_loss': 0.255646,
#    'val_rate': 0.255646,
#    'val_mse': 1.10466},
#   {'epoch': 8,
#    'loss': 0.242355,
#    'rate': 0.242355,
#    'mse': 1.10271,
#    'val_loss': 0.223959,
#    'val_rate': 0.223959,
#    'val_mse': 1.10114},
#   {'epoch': 9,
#    'loss': 0.225765,
#    'rate': 0.225765,
#    'mse': 1.10128,
#    'val_loss': 0.222908,
#    'val_rate': 0.222908,
#    'val_mse': 1.10405},
#   {'epoch': 10,
#    'loss': 0.0480106,
#    'rate': 0.0480106,
#    'mse': 1.10075,
#    'val_loss': 0.0504869,
#    'val_rate': 0.0504869,
#    'val_mse': 1.10246},
#   {'epoch': 11,
#    'loss': 0.0480474,
#    'rate': 0.0480474,
#    'mse': 1.10064,
#    'val_loss': 0.0510278,
#    'val_rate': 0.0510278,
#    'val_mse': 1.10295},
#   {'epoch': 12,
#    'loss': 0.0479277,
#    'rate': 0.0479277,
#    'mse': 1.10048,
#    'val_loss': 0.0555739,
#    'val_rate': 0.0555739,
#    'val_mse': 1.10391},
#   {'epoch': 13,
#    'loss': 0.0475153,
#    'rate': 0.0475153,
#    'mse': 1.10058,
#    'val_loss': 0.0455773,
#    'val_rate': 0.0455773,
#    'val_mse': 1.10011},
#   {'epoch': 14,
#    'loss': 0.0476068,
#    'rate': 0.0476068,
#    'mse': 1.10043,
#    'val_loss': 0.0435038,
#    'val_rate': 0.0435038,
#    'val_mse': 1.10005},
#   {'epoch': 15,
#    'loss': 0.0111294,
#    'rate': 0.0111294,
#    'mse': 1.10047,
#    'val_loss': 0.0102403,
#    'val_rate': 0.0102403,
#    'val_mse': 1.1001},
#   {'epoch': 16,
#    'loss': 0.00983586,
#    'rate': 0.00983586,
#    'mse': 1.10044,
#    'val_loss': 0.00987318,
#    'val_rate': 0.00987318,
#    'val_mse': 1.10095},
#   {'epoch': 17,
#    'loss': 0.00990515,
#    'rate': 0.00990515,
#    'mse': 1.10049,
#    'val_loss': 0.00995653,
#    'val_rate': 0.00995653,
#    'val_mse': 1.10084},
#   {'epoch': 18,
#    'loss': 0.00343082,
#    'rate': 0.00343082,
#    'mse': 1.10044,
#    'val_loss': 0.00227507,
#    'val_rate': 0.00227507,
#    'val_mse': 1.10085},
#   {'epoch': 19,
#    'loss': 0.00223985,
#    'rate': 0.00223985,
#    'mse': 1.10041,
#    'val_loss': 0.00233035,
#    'val_rate': 0.00233035,
#    'val_mse': 1.10042}],
#  3e-19: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 1,
#    'loss': 0.77247,
#    'rate': 0.77247,
#    'mse': 1.11801,
#    'val_loss': 0.644285,
#    'val_rate': 0.644285,
#    'val_mse': 1.11305},
#   {'epoch': 2,
#    'loss': 0.589531,
#    'rate': 0.589531,
#    'mse': 1.11475,
#    'val_loss': 0.489801,
#    'val_rate': 0.489801,
#    'val_mse': 1.10998},
#   {'epoch': 3,
#    'loss': 0.479843,
#    'rate': 0.479843,
#    'mse': 1.1121,
#    'val_loss': 0.4885,
#    'val_rate': 0.4885,
#    'val_mse': 1.11831},
#   {'epoch': 4,
#    'loss': 0.397131,
#    'rate': 0.397131,
#    'mse': 1.10967,
#    'val_loss': 0.355159,
#    'val_rate': 0.355159,
#    'val_mse': 1.10793},
#   {'epoch': 5,
#    'loss': 0.337429,
#    'rate': 0.337429,
#    'mse': 1.10767,
#    'val_loss': 0.303286,
#    'val_rate': 0.303286,
#    'val_mse': 1.10348},
#   {'epoch': 6,
#    'loss': 0.297397,
#    'rate': 0.297397,
#    'mse': 1.10576,
#    'val_loss': 0.27841,
#    'val_rate': 0.27841,
#    'val_mse': 1.1093},
#   {'epoch': 7,
#    'loss': 0.265545,
#    'rate': 0.265545,
#    'mse': 1.10424,
#    'val_loss': 0.254978,
#    'val_rate': 0.254978,
#    'val_mse': 1.10452},
#   {'epoch': 8,
#    'loss': 0.242228,
#    'rate': 0.242228,
#    'mse': 1.10271,
#    'val_loss': 0.224233,
#    'val_rate': 0.224233,
#    'val_mse': 1.10098},
#   {'epoch': 9,
#    'loss': 0.225878,
#    'rate': 0.225878,
#    'mse': 1.10129,
#    'val_loss': 0.224168,
#    'val_rate': 0.224168,
#    'val_mse': 1.10421},
#   {'epoch': 10,
#    'loss': 0.0479989,
#    'rate': 0.0479989,
#    'mse': 1.10075,
#    'val_loss': 0.0504903,
#    'val_rate': 0.0504903,
#    'val_mse': 1.10244},
#   {'epoch': 11,
#    'loss': 0.0480531,
#    'rate': 0.0480531,
#    'mse': 1.10065,
#    'val_loss': 0.0502659,
#    'val_rate': 0.0502659,
#    'val_mse': 1.10278},
#   {'epoch': 12,
#    'loss': 0.047937,
#    'rate': 0.047937,
#    'mse': 1.10048,
#    'val_loss': 0.0563413,
#    'val_rate': 0.0563413,
#    'val_mse': 1.10402},
#   {'epoch': 13,
#    'loss': 0.047497,
#    'rate': 0.047497,
#    'mse': 1.10058,
#    'val_loss': 0.0455614,
#    'val_rate': 0.0455614,
#    'val_mse': 1.10011},
#   {'epoch': 14,
#    'loss': 0.0476037,
#    'rate': 0.0476037,
#    'mse': 1.10043,
#    'val_loss': 0.0433169,
#    'val_rate': 0.0433169,
#    'val_mse': 1.10016},
#   {'epoch': 15,
#    'loss': 0.0111377,
#    'rate': 0.0111377,
#    'mse': 1.10046,
#    'val_loss': 0.0102338,
#    'val_rate': 0.0102338,
#    'val_mse': 1.10008},
#   {'epoch': 16,
#    'loss': 0.00983139,
#    'rate': 0.00983139,
#    'mse': 1.10044,
#    'val_loss': 0.00998736,
#    'val_rate': 0.00998736,
#    'val_mse': 1.10107},
#   {'epoch': 17,
#    'loss': 0.00991034,
#    'rate': 0.00991034,
#    'mse': 1.10049,
#    'val_loss': 0.0101488,
#    'val_rate': 0.0101488,
#    'val_mse': 1.10095},
#   {'epoch': 18,
#    'loss': 0.00341497,
#    'rate': 0.00341497,
#    'mse': 1.10044,
#    'val_loss': 0.00224568,
#    'val_rate': 0.00224568,
#    'val_mse': 1.10085},
#   {'epoch': 19,
#    'loss': 0.00224273,
#    'rate': 0.00224273,
#    'mse': 1.10041,
#    'val_loss': 0.00238972,
#    'val_rate': 0.00238972,
#    'val_mse': 1.10051}],
#  1e-18: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837389,
#    'val_rate': 0.837389,
#    'val_mse': 1.11881},
#   {'epoch': 1,
#    'loss': 0.772451,
#    'rate': 0.772451,
#    'mse': 1.11801,
#    'val_loss': 0.64458,
#    'val_rate': 0.64458,
#    'val_mse': 1.11302},
#   {'epoch': 2,
#    'loss': 0.589459,
#    'rate': 0.589459,
#    'mse': 1.11475,
#    'val_loss': 0.486147,
#    'val_rate': 0.486147,
#    'val_mse': 1.11059},
#   {'epoch': 3,
#    'loss': 0.479916,
#    'rate': 0.479916,
#    'mse': 1.1121,
#    'val_loss': 0.488291,
#    'val_rate': 0.488291,
#    'val_mse': 1.1183},
#   {'epoch': 4,
#    'loss': 0.397102,
#    'rate': 0.397102,
#    'mse': 1.10968,
#    'val_loss': 0.355662,
#    'val_rate': 0.355662,
#    'val_mse': 1.10776},
#   {'epoch': 5,
#    'loss': 0.337342,
#    'rate': 0.337342,
#    'mse': 1.10767,
#    'val_loss': 0.299358,
#    'val_rate': 0.299358,
#    'val_mse': 1.10398},
#   {'epoch': 6,
#    'loss': 0.297335,
#    'rate': 0.297335,
#    'mse': 1.10576,
#    'val_loss': 0.279424,
#    'val_rate': 0.279424,
#    'val_mse': 1.10939},
#   {'epoch': 7,
#    'loss': 0.265262,
#    'rate': 0.265262,
#    'mse': 1.10424,
#    'val_loss': 0.256094,
#    'val_rate': 0.256094,
#    'val_mse': 1.10473},
#   {'epoch': 8,
#    'loss': 0.242393,
#    'rate': 0.242393,
#    'mse': 1.10271,
#    'val_loss': 0.223945,
#    'val_rate': 0.223945,
#    'val_mse': 1.10115},
#   {'epoch': 9,
#    'loss': 0.225828,
#    'rate': 0.225828,
#    'mse': 1.10128,
#    'val_loss': 0.223626,
#    'val_rate': 0.223626,
#    'val_mse': 1.10415},
#   {'epoch': 10,
#    'loss': 0.0480049,
#    'rate': 0.0480049,
#    'mse': 1.10075,
#    'val_loss': 0.0505099,
#    'val_rate': 0.0505099,
#    'val_mse': 1.10247},
#   {'epoch': 11,
#    'loss': 0.048039,
#    'rate': 0.048039,
#    'mse': 1.10064,
#    'val_loss': 0.0505268,
#    'val_rate': 0.0505268,
#    'val_mse': 1.10284},
#   {'epoch': 12,
#    'loss': 0.0479367,
#    'rate': 0.0479367,
#    'mse': 1.10048,
#    'val_loss': 0.0558789,
#    'val_rate': 0.0558789,
#    'val_mse': 1.10394},
#   {'epoch': 13,
#    'loss': 0.0474862,
#    'rate': 0.0474862,
#    'mse': 1.10058,
#    'val_loss': 0.0456957,
#    'val_rate': 0.0456957,
#    'val_mse': 1.10031},
#   {'epoch': 14,
#    'loss': 0.0476372,
#    'rate': 0.0476372,
#    'mse': 1.10043,
#    'val_loss': 0.0433147,
#    'val_rate': 0.0433147,
#    'val_mse': 1.10017},
#   {'epoch': 15,
#    'loss': 0.0111291,
#    'rate': 0.0111291,
#    'mse': 1.10046,
#    'val_loss': 0.0102237,
#    'val_rate': 0.0102237,
#    'val_mse': 1.10009},
#   {'epoch': 16,
#    'loss': 0.00983223,
#    'rate': 0.00983223,
#    'mse': 1.10044,
#    'val_loss': 0.0101867,
#    'val_rate': 0.0101867,
#    'val_mse': 1.10122},
#   {'epoch': 17,
#    'loss': 0.0099075,
#    'rate': 0.0099075,
#    'mse': 1.10049,
#    'val_loss': 0.0100884,
#    'val_rate': 0.0100884,
#    'val_mse': 1.10093},
#   {'epoch': 18,
#    'loss': 0.00341828,
#    'rate': 0.00341828,
#    'mse': 1.10044,
#    'val_loss': 0.00226742,
#    'val_rate': 0.00226742,
#    'val_mse': 1.10084},
#   {'epoch': 19,
#    'loss': 0.00224136,
#    'rate': 0.00224136,
#    'mse': 1.10041,
#    'val_loss': 0.00234249,
#    'val_rate': 0.00234249,
#    'val_mse': 1.10042}],
#  3e-18: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 1,
#    'loss': 0.77247,
#    'rate': 0.77247,
#    'mse': 1.11801,
#    'val_loss': 0.644285,
#    'val_rate': 0.644285,
#    'val_mse': 1.11305},
#   {'epoch': 2,
#    'loss': 0.589531,
#    'rate': 0.589531,
#    'mse': 1.11475,
#    'val_loss': 0.489801,
#    'val_rate': 0.489801,
#    'val_mse': 1.10998},
#   {'epoch': 3,
#    'loss': 0.479843,
#    'rate': 0.479843,
#    'mse': 1.1121,
#    'val_loss': 0.4885,
#    'val_rate': 0.4885,
#    'val_mse': 1.11831},
#   {'epoch': 4,
#    'loss': 0.397131,
#    'rate': 0.397131,
#    'mse': 1.10967,
#    'val_loss': 0.355159,
#    'val_rate': 0.355159,
#    'val_mse': 1.10793},
#   {'epoch': 5,
#    'loss': 0.337429,
#    'rate': 0.337429,
#    'mse': 1.10767,
#    'val_loss': 0.303286,
#    'val_rate': 0.303286,
#    'val_mse': 1.10348},
#   {'epoch': 6,
#    'loss': 0.297397,
#    'rate': 0.297397,
#    'mse': 1.10576,
#    'val_loss': 0.27841,
#    'val_rate': 0.27841,
#    'val_mse': 1.1093},
#   {'epoch': 7,
#    'loss': 0.265545,
#    'rate': 0.265545,
#    'mse': 1.10424,
#    'val_loss': 0.254978,
#    'val_rate': 0.254978,
#    'val_mse': 1.10452},
#   {'epoch': 8,
#    'loss': 0.242228,
#    'rate': 0.242228,
#    'mse': 1.10271,
#    'val_loss': 0.224233,
#    'val_rate': 0.224233,
#    'val_mse': 1.10098},
#   {'epoch': 9,
#    'loss': 0.225878,
#    'rate': 0.225878,
#    'mse': 1.10129,
#    'val_loss': 0.224168,
#    'val_rate': 0.224168,
#    'val_mse': 1.10421},
#   {'epoch': 10,
#    'loss': 0.0479989,
#    'rate': 0.0479989,
#    'mse': 1.10075,
#    'val_loss': 0.0504903,
#    'val_rate': 0.0504903,
#    'val_mse': 1.10244},
#   {'epoch': 11,
#    'loss': 0.0480531,
#    'rate': 0.0480531,
#    'mse': 1.10065,
#    'val_loss': 0.0502659,
#    'val_rate': 0.0502659,
#    'val_mse': 1.10278},
#   {'epoch': 12,
#    'loss': 0.047937,
#    'rate': 0.047937,
#    'mse': 1.10048,
#    'val_loss': 0.0563413,
#    'val_rate': 0.0563413,
#    'val_mse': 1.10402},
#   {'epoch': 13,
#    'loss': 0.047497,
#    'rate': 0.047497,
#    'mse': 1.10058,
#    'val_loss': 0.0455614,
#    'val_rate': 0.0455614,
#    'val_mse': 1.10011},
#   {'epoch': 14,
#    'loss': 0.0476037,
#    'rate': 0.0476037,
#    'mse': 1.10043,
#    'val_loss': 0.0433169,
#    'val_rate': 0.0433169,
#    'val_mse': 1.10016},
#   {'epoch': 15,
#    'loss': 0.0111377,
#    'rate': 0.0111377,
#    'mse': 1.10046,
#    'val_loss': 0.0102338,
#    'val_rate': 0.0102338,
#    'val_mse': 1.10008},
#   {'epoch': 16,
#    'loss': 0.00983139,
#    'rate': 0.00983139,
#    'mse': 1.10044,
#    'val_loss': 0.00998736,
#    'val_rate': 0.00998736,
#    'val_mse': 1.10107},
#   {'epoch': 17,
#    'loss': 0.00991034,
#    'rate': 0.00991034,
#    'mse': 1.10049,
#    'val_loss': 0.0101488,
#    'val_rate': 0.0101488,
#    'val_mse': 1.10095},
#   {'epoch': 18,
#    'loss': 0.00341497,
#    'rate': 0.00341497,
#    'mse': 1.10044,
#    'val_loss': 0.00224568,
#    'val_rate': 0.00224568,
#    'val_mse': 1.10085},
#   {'epoch': 19,
#    'loss': 0.00224273,
#    'rate': 0.00224273,
#    'mse': 1.10041,
#    'val_loss': 0.00238972,
#    'val_rate': 0.00238972,
#    'val_mse': 1.10051}],
#  1e-17: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837411,
#    'val_rate': 0.837411,
#    'val_mse': 1.11889},
#   {'epoch': 1,
#    'loss': 0.772476,
#    'rate': 0.772476,
#    'mse': 1.11801,
#    'val_loss': 0.644005,
#    'val_rate': 0.644005,
#    'val_mse': 1.11308},
#   {'epoch': 2,
#    'loss': 0.589445,
#    'rate': 0.589445,
#    'mse': 1.11475,
#    'val_loss': 0.485817,
#    'val_rate': 0.485817,
#    'val_mse': 1.11066},
#   {'epoch': 3,
#    'loss': 0.479936,
#    'rate': 0.479936,
#    'mse': 1.1121,
#    'val_loss': 0.491659,
#    'val_rate': 0.491659,
#    'val_mse': 1.11848},
#   {'epoch': 4,
#    'loss': 0.397126,
#    'rate': 0.397126,
#    'mse': 1.10967,
#    'val_loss': 0.355007,
#    'val_rate': 0.355007,
#    'val_mse': 1.10799},
#   {'epoch': 5,
#    'loss': 0.337512,
#    'rate': 0.337512,
#    'mse': 1.10767,
#    'val_loss': 0.306177,
#    'val_rate': 0.306177,
#    'val_mse': 1.10315},
#   {'epoch': 6,
#    'loss': 0.297332,
#    'rate': 0.297332,
#    'mse': 1.10576,
#    'val_loss': 0.278794,
#    'val_rate': 0.278794,
#    'val_mse': 1.10933},
#   {'epoch': 7,
#    'loss': 0.265495,
#    'rate': 0.265495,
#    'mse': 1.10424,
#    'val_loss': 0.254445,
#    'val_rate': 0.254445,
#    'val_mse': 1.10441},
#   {'epoch': 8,
#    'loss': 0.242275,
#    'rate': 0.242275,
#    'mse': 1.10271,
#    'val_loss': 0.224017,
#    'val_rate': 0.224017,
#    'val_mse': 1.1011},
#   {'epoch': 9,
#    'loss': 0.225885,
#    'rate': 0.225885,
#    'mse': 1.10128,
#    'val_loss': 0.223031,
#    'val_rate': 0.223031,
#    'val_mse': 1.10405},
#   {'epoch': 10,
#    'loss': 0.04801,
#    'rate': 0.04801,
#    'mse': 1.10075,
#    'val_loss': 0.0502469,
#    'val_rate': 0.0502469,
#    'val_mse': 1.10239},
#   {'epoch': 11,
#    'loss': 0.0480475,
#    'rate': 0.0480475,
#    'mse': 1.10064,
#    'val_loss': 0.0510446,
#    'val_rate': 0.0510446,
#    'val_mse': 1.10295},
#   {'epoch': 12,
#    'loss': 0.0479196,
#    'rate': 0.0479196,
#    'mse': 1.10048,
#    'val_loss': 0.0558334,
#    'val_rate': 0.0558334,
#    'val_mse': 1.10394},
#   {'epoch': 13,
#    'loss': 0.0475072,
#    'rate': 0.0475072,
#    'mse': 1.10058,
#    'val_loss': 0.0456627,
#    'val_rate': 0.0456627,
#    'val_mse': 1.10026},
#   {'epoch': 14,
#    'loss': 0.0476077,
#    'rate': 0.0476077,
#    'mse': 1.10043,
#    'val_loss': 0.0433173,
#    'val_rate': 0.0433173,
#    'val_mse': 1.10019},
#   {'epoch': 15,
#    'loss': 0.0111278,
#    'rate': 0.0111278,
#    'mse': 1.10046,
#    'val_loss': 0.010268,
#    'val_rate': 0.010268,
#    'val_mse': 1.10003},
#   {'epoch': 16,
#    'loss': 0.00984167,
#    'rate': 0.00984167,
#    'mse': 1.10044,
#    'val_loss': 0.0100149,
#    'val_rate': 0.0100149,
#    'val_mse': 1.10106},
#   {'epoch': 17,
#    'loss': 0.00989977,
#    'rate': 0.00989977,
#    'mse': 1.10049,
#    'val_loss': 0.0101513,
#    'val_rate': 0.0101513,
#    'val_mse': 1.10096},
#   {'epoch': 18,
#    'loss': 0.00342908,
#    'rate': 0.00342908,
#    'mse': 1.10044,
#    'val_loss': 0.00224575,
#    'val_rate': 0.00224575,
#    'val_mse': 1.10083},
#   {'epoch': 19,
#    'loss': 0.00224674,
#    'rate': 0.00224674,
#    'mse': 1.10041,
#    'val_loss': 0.00240149,
#    'val_rate': 0.00240149,
#    'val_mse': 1.10049}],
#  3e-17: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 1,
#    'loss': 0.772445,
#    'rate': 0.772445,
#    'mse': 1.11801,
#    'val_loss': 0.644965,
#    'val_rate': 0.644965,
#    'val_mse': 1.11298},
#   {'epoch': 2,
#    'loss': 0.589613,
#    'rate': 0.589613,
#    'mse': 1.11475,
#    'val_loss': 0.490346,
#    'val_rate': 0.490346,
#    'val_mse': 1.1099},
#   {'epoch': 3,
#    'loss': 0.479806,
#    'rate': 0.479806,
#    'mse': 1.1121,
#    'val_loss': 0.48871,
#    'val_rate': 0.48871,
#    'val_mse': 1.11832},
#   {'epoch': 4,
#    'loss': 0.397112,
#    'rate': 0.397112,
#    'mse': 1.10968,
#    'val_loss': 0.355642,
#    'val_rate': 0.355642,
#    'val_mse': 1.10772},
#   {'epoch': 5,
#    'loss': 0.337418,
#    'rate': 0.337418,
#    'mse': 1.10767,
#    'val_loss': 0.302293,
#    'val_rate': 0.302293,
#    'val_mse': 1.1036},
#   {'epoch': 6,
#    'loss': 0.297369,
#    'rate': 0.297369,
#    'mse': 1.10576,
#    'val_loss': 0.279076,
#    'val_rate': 0.279076,
#    'val_mse': 1.10936},
#   {'epoch': 7,
#    'loss': 0.265266,
#    'rate': 0.265266,
#    'mse': 1.10424,
#    'val_loss': 0.255868,
#    'val_rate': 0.255868,
#    'val_mse': 1.10468},
#   {'epoch': 8,
#    'loss': 0.242297,
#    'rate': 0.242297,
#    'mse': 1.10271,
#    'val_loss': 0.223688,
#    'val_rate': 0.223688,
#    'val_mse': 1.10139},
#   {'epoch': 9,
#    'loss': 0.225852,
#    'rate': 0.225852,
#    'mse': 1.10128,
#    'val_loss': 0.224223,
#    'val_rate': 0.224223,
#    'val_mse': 1.10422},
#   {'epoch': 10,
#    'loss': 0.048004,
#    'rate': 0.048004,
#    'mse': 1.10075,
#    'val_loss': 0.049847,
#    'val_rate': 0.049847,
#    'val_mse': 1.10227},
#   {'epoch': 11,
#    'loss': 0.0480477,
#    'rate': 0.0480477,
#    'mse': 1.10064,
#    'val_loss': 0.0505501,
#    'val_rate': 0.0505501,
#    'val_mse': 1.10284},
#   {'epoch': 12,
#    'loss': 0.0479118,
#    'rate': 0.0479118,
#    'mse': 1.10048,
#    'val_loss': 0.0562074,
#    'val_rate': 0.0562074,
#    'val_mse': 1.104},
#   {'epoch': 13,
#    'loss': 0.0474985,
#    'rate': 0.0474985,
#    'mse': 1.10058,
#    'val_loss': 0.0455763,
#    'val_rate': 0.0455763,
#    'val_mse': 1.10021},
#   {'epoch': 14,
#    'loss': 0.0476119,
#    'rate': 0.0476119,
#    'mse': 1.10043,
#    'val_loss': 0.0434343,
#    'val_rate': 0.0434343,
#    'val_mse': 1.10008},
#   {'epoch': 15,
#    'loss': 0.0111435,
#    'rate': 0.0111435,
#    'mse': 1.10046,
#    'val_loss': 0.010283,
#    'val_rate': 0.010283,
#    'val_mse': 1.10003},
#   {'epoch': 16,
#    'loss': 0.00983412,
#    'rate': 0.00983412,
#    'mse': 1.10044,
#    'val_loss': 0.0100715,
#    'val_rate': 0.0100715,
#    'val_mse': 1.10113},
#   {'epoch': 17,
#    'loss': 0.00991444,
#    'rate': 0.00991444,
#    'mse': 1.10049,
#    'val_loss': 0.0100094,
#    'val_rate': 0.0100094,
#    'val_mse': 1.10088},
#   {'epoch': 18,
#    'loss': 0.00341291,
#    'rate': 0.00341291,
#    'mse': 1.10044,
#    'val_loss': 0.0022928,
#    'val_rate': 0.0022928,
#    'val_mse': 1.10084},
#   {'epoch': 19,
#    'loss': 0.00223973,
#    'rate': 0.00223973,
#    'mse': 1.10041,
#    'val_loss': 0.00236444,
#    'val_rate': 0.00236444,
#    'val_mse': 1.10046}],
#  1e-16: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837466,
#    'val_rate': 0.837466,
#    'val_mse': 1.11887},
#   {'epoch': 1,
#    'loss': 0.772484,
#    'rate': 0.772484,
#    'mse': 1.11801,
#    'val_loss': 0.644301,
#    'val_rate': 0.644301,
#    'val_mse': 1.11305},
#   {'epoch': 2,
#    'loss': 0.589555,
#    'rate': 0.589555,
#    'mse': 1.11475,
#    'val_loss': 0.490111,
#    'val_rate': 0.490111,
#    'val_mse': 1.10993},
#   {'epoch': 3,
#    'loss': 0.479852,
#    'rate': 0.479852,
#    'mse': 1.1121,
#    'val_loss': 0.486913,
#    'val_rate': 0.486913,
#    'val_mse': 1.11823},
#   {'epoch': 4,
#    'loss': 0.39715,
#    'rate': 0.39715,
#    'mse': 1.10967,
#    'val_loss': 0.355304,
#    'val_rate': 0.355304,
#    'val_mse': 1.10789},
#   {'epoch': 5,
#    'loss': 0.337436,
#    'rate': 0.337436,
#    'mse': 1.10767,
#    'val_loss': 0.304433,
#    'val_rate': 0.304433,
#    'val_mse': 1.10335},
#   {'epoch': 6,
#    'loss': 0.297338,
#    'rate': 0.297338,
#    'mse': 1.10576,
#    'val_loss': 0.279461,
#    'val_rate': 0.279461,
#    'val_mse': 1.10941},
#   {'epoch': 7,
#    'loss': 0.265349,
#    'rate': 0.265349,
#    'mse': 1.10424,
#    'val_loss': 0.255567,
#    'val_rate': 0.255567,
#    'val_mse': 1.10466},
#   {'epoch': 8,
#    'loss': 0.242288,
#    'rate': 0.242288,
#    'mse': 1.10271,
#    'val_loss': 0.224073,
#    'val_rate': 0.224073,
#    'val_mse': 1.1011},
#   {'epoch': 9,
#    'loss': 0.225853,
#    'rate': 0.225853,
#    'mse': 1.10128,
#    'val_loss': 0.226964,
#    'val_rate': 0.226964,
#    'val_mse': 1.10456},
#   {'epoch': 10,
#    'loss': 0.0479966,
#    'rate': 0.0479966,
#    'mse': 1.10075,
#    'val_loss': 0.0507582,
#    'val_rate': 0.0507582,
#    'val_mse': 1.10253},
#   {'epoch': 11,
#    'loss': 0.0480562,
#    'rate': 0.0480562,
#    'mse': 1.10065,
#    'val_loss': 0.0502884,
#    'val_rate': 0.0502884,
#    'val_mse': 1.10279},
#   {'epoch': 12,
#    'loss': 0.0479283,
#    'rate': 0.0479283,
#    'mse': 1.10048,
#    'val_loss': 0.0559088,
#    'val_rate': 0.0559088,
#    'val_mse': 1.10396},
#   {'epoch': 13,
#    'loss': 0.0474977,
#    'rate': 0.0474977,
#    'mse': 1.10058,
#    'val_loss': 0.0456,
#    'val_rate': 0.0456,
#    'val_mse': 1.1002},
#   {'epoch': 14,
#    'loss': 0.0476077,
#    'rate': 0.0476077,
#    'mse': 1.10043,
#    'val_loss': 0.0432553,
#    'val_rate': 0.0432553,
#    'val_mse': 1.10022},
#   {'epoch': 15,
#    'loss': 0.0111353,
#    'rate': 0.0111353,
#    'mse': 1.10046,
#    'val_loss': 0.0101973,
#    'val_rate': 0.0101973,
#    'val_mse': 1.10015},
#   {'epoch': 16,
#    'loss': 0.00982366,
#    'rate': 0.00982366,
#    'mse': 1.10044,
#    'val_loss': 0.00989249,
#    'val_rate': 0.00989249,
#    'val_mse': 1.10099},
#   {'epoch': 17,
#    'loss': 0.00990395,
#    'rate': 0.00990395,
#    'mse': 1.10049,
#    'val_loss': 0.0101304,
#    'val_rate': 0.0101304,
#    'val_mse': 1.10095},
#   {'epoch': 18,
#    'loss': 0.00342238,
#    'rate': 0.00342238,
#    'mse': 1.10044,
#    'val_loss': 0.00220769,
#    'val_rate': 0.00220769,
#    'val_mse': 1.10082},
#   {'epoch': 19,
#    'loss': 0.00223428,
#    'rate': 0.00223428,
#    'mse': 1.10041,
#    'val_loss': 0.00243085,
#    'val_rate': 0.00243085,
#    'val_mse': 1.10055}],
#  3e-16: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11882},
#   {'epoch': 1,
#    'loss': 0.772481,
#    'rate': 0.772481,
#    'mse': 1.11801,
#    'val_loss': 0.644713,
#    'val_rate': 0.644713,
#    'val_mse': 1.11301},
#   {'epoch': 2,
#    'loss': 0.589532,
#    'rate': 0.589532,
#    'mse': 1.11475,
#    'val_loss': 0.489107,
#    'val_rate': 0.489107,
#    'val_mse': 1.11008},
#   {'epoch': 3,
#    'loss': 0.479823,
#    'rate': 0.479823,
#    'mse': 1.1121,
#    'val_loss': 0.489916,
#    'val_rate': 0.489916,
#    'val_mse': 1.11839},
#   {'epoch': 4,
#    'loss': 0.397117,
#    'rate': 0.397117,
#    'mse': 1.10968,
#    'val_loss': 0.355656,
#    'val_rate': 0.355656,
#    'val_mse': 1.10776},
#   {'epoch': 5,
#    'loss': 0.337346,
#    'rate': 0.337346,
#    'mse': 1.10767,
#    'val_loss': 0.299538,
#    'val_rate': 0.299538,
#    'val_mse': 1.10395},
#   {'epoch': 6,
#    'loss': 0.297466,
#    'rate': 0.297466,
#    'mse': 1.10576,
#    'val_loss': 0.279587,
#    'val_rate': 0.279587,
#    'val_mse': 1.10942},
#   {'epoch': 7,
#    'loss': 0.265176,
#    'rate': 0.265176,
#    'mse': 1.10424,
#    'val_loss': 0.256679,
#    'val_rate': 0.256679,
#    'val_mse': 1.10483},
#   {'epoch': 8,
#    'loss': 0.242415,
#    'rate': 0.242415,
#    'mse': 1.10271,
#    'val_loss': 0.224036,
#    'val_rate': 0.224036,
#    'val_mse': 1.10106},
#   {'epoch': 9,
#    'loss': 0.225854,
#    'rate': 0.225854,
#    'mse': 1.10128,
#    'val_loss': 0.223995,
#    'val_rate': 0.223995,
#    'val_mse': 1.10419},
#   {'epoch': 10,
#    'loss': 0.0480026,
#    'rate': 0.0480026,
#    'mse': 1.10075,
#    'val_loss': 0.0503053,
#    'val_rate': 0.0503053,
#    'val_mse': 1.1024},
#   {'epoch': 11,
#    'loss': 0.0480396,
#    'rate': 0.0480396,
#    'mse': 1.10064,
#    'val_loss': 0.0506522,
#    'val_rate': 0.0506522,
#    'val_mse': 1.10287},
#   {'epoch': 12,
#    'loss': 0.0479225,
#    'rate': 0.0479225,
#    'mse': 1.10048,
#    'val_loss': 0.0561491,
#    'val_rate': 0.0561491,
#    'val_mse': 1.10399},
#   {'epoch': 13,
#    'loss': 0.0475008,
#    'rate': 0.0475008,
#    'mse': 1.10058,
#    'val_loss': 0.045593,
#    'val_rate': 0.045593,
#    'val_mse': 1.10018},
#   {'epoch': 14,
#    'loss': 0.04761,
#    'rate': 0.04761,
#    'mse': 1.10043,
#    'val_loss': 0.0434226,
#    'val_rate': 0.0434226,
#    'val_mse': 1.10009},
#   {'epoch': 15,
#    'loss': 0.0111327,
#    'rate': 0.0111327,
#    'mse': 1.10046,
#    'val_loss': 0.0102451,
#    'val_rate': 0.0102451,
#    'val_mse': 1.1001},
#   {'epoch': 16,
#    'loss': 0.00983664,
#    'rate': 0.00983664,
#    'mse': 1.10044,
#    'val_loss': 0.00996864,
#    'val_rate': 0.00996864,
#    'val_mse': 1.1011},
#   {'epoch': 17,
#    'loss': 0.00990718,
#    'rate': 0.00990718,
#    'mse': 1.10049,
#    'val_loss': 0.0101859,
#    'val_rate': 0.0101859,
#    'val_mse': 1.10096},
#   {'epoch': 18,
#    'loss': 0.00342545,
#    'rate': 0.00342545,
#    'mse': 1.10044,
#    'val_loss': 0.00226054,
#    'val_rate': 0.00226054,
#    'val_mse': 1.10083},
#   {'epoch': 19,
#    'loss': 0.00224479,
#    'rate': 0.00224479,
#    'mse': 1.10041,
#    'val_loss': 0.00235888,
#    'val_rate': 0.00235888,
#    'val_mse': 1.10047}],
#  1e-15: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837414,
#    'val_rate': 0.837414,
#    'val_mse': 1.11885},
#   {'epoch': 1,
#    'loss': 0.772487,
#    'rate': 0.772487,
#    'mse': 1.11801,
#    'val_loss': 0.644598,
#    'val_rate': 0.644598,
#    'val_mse': 1.11302},
#   {'epoch': 2,
#    'loss': 0.589543,
#    'rate': 0.589543,
#    'mse': 1.11475,
#    'val_loss': 0.488747,
#    'val_rate': 0.488747,
#    'val_mse': 1.11014},
#   {'epoch': 3,
#    'loss': 0.479867,
#    'rate': 0.479867,
#    'mse': 1.1121,
#    'val_loss': 0.488585,
#    'val_rate': 0.488585,
#    'val_mse': 1.11831},
#   {'epoch': 4,
#    'loss': 0.397077,
#    'rate': 0.397077,
#    'mse': 1.10967,
#    'val_loss': 0.356238,
#    'val_rate': 0.356238,
#    'val_mse': 1.10759},
#   {'epoch': 5,
#    'loss': 0.337397,
#    'rate': 0.337397,
#    'mse': 1.10767,
#    'val_loss': 0.300583,
#    'val_rate': 0.300583,
#    'val_mse': 1.10382},
#   {'epoch': 6,
#    'loss': 0.297402,
#    'rate': 0.297402,
#    'mse': 1.10576,
#    'val_loss': 0.280302,
#    'val_rate': 0.280302,
#    'val_mse': 1.1095},
#   {'epoch': 7,
#    'loss': 0.265429,
#    'rate': 0.265429,
#    'mse': 1.10424,
#    'val_loss': 0.255338,
#    'val_rate': 0.255338,
#    'val_mse': 1.10459},
#   {'epoch': 8,
#    'loss': 0.242314,
#    'rate': 0.242314,
#    'mse': 1.10271,
#    'val_loss': 0.224013,
#    'val_rate': 0.224013,
#    'val_mse': 1.10108},
#   {'epoch': 9,
#    'loss': 0.225843,
#    'rate': 0.225843,
#    'mse': 1.10128,
#    'val_loss': 0.223403,
#    'val_rate': 0.223403,
#    'val_mse': 1.10411},
#   {'epoch': 10,
#    'loss': 0.0479892,
#    'rate': 0.0479892,
#    'mse': 1.10075,
#    'val_loss': 0.0501063,
#    'val_rate': 0.0501063,
#    'val_mse': 1.10234},
#   {'epoch': 11,
#    'loss': 0.0480293,
#    'rate': 0.0480293,
#    'mse': 1.10064,
#    'val_loss': 0.0507132,
#    'val_rate': 0.0507132,
#    'val_mse': 1.10288},
#   {'epoch': 12,
#    'loss': 0.0479361,
#    'rate': 0.0479361,
#    'mse': 1.10048,
#    'val_loss': 0.0558679,
#    'val_rate': 0.0558679,
#    'val_mse': 1.10395},
#   {'epoch': 13,
#    'loss': 0.0474859,
#    'rate': 0.0474859,
#    'mse': 1.10058,
#    'val_loss': 0.0457153,
#    'val_rate': 0.0457153,
#    'val_mse': 1.10031},
#   {'epoch': 14,
#    'loss': 0.0475988,
#    'rate': 0.0475988,
#    'mse': 1.10043,
#    'val_loss': 0.0433283,
#    'val_rate': 0.0433283,
#    'val_mse': 1.10015},
#   {'epoch': 15,
#    'loss': 0.0111225,
#    'rate': 0.0111225,
#    'mse': 1.10046,
#    'val_loss': 0.0102451,
#    'val_rate': 0.0102451,
#    'val_mse': 1.10005},
#   {'epoch': 16,
#    'loss': 0.00982832,
#    'rate': 0.00982832,
#    'mse': 1.10044,
#    'val_loss': 0.0099997,
#    'val_rate': 0.0099997,
#    'val_mse': 1.10108},
#   {'epoch': 17,
#    'loss': 0.0099104,
#    'rate': 0.0099104,
#    'mse': 1.10049,
#    'val_loss': 0.0101459,
#    'val_rate': 0.0101459,
#    'val_mse': 1.10095},
#   {'epoch': 18,
#    'loss': 0.00341757,
#    'rate': 0.00341757,
#    'mse': 1.10044,
#    'val_loss': 0.00228647,
#    'val_rate': 0.00228647,
#    'val_mse': 1.10086},
#   {'epoch': 19,
#    'loss': 0.00223575,
#    'rate': 0.00223575,
#    'mse': 1.10041,
#    'val_loss': 0.00235288,
#    'val_rate': 0.00235288,
#    'val_mse': 1.10042}],
#  3e-15: [{'epoch': 0,
#    'loss': 3.63896,
#    'rate': 3.63896,
#    'mse': 1.12019,
#    'val_loss': 0.837452,
#    'val_rate': 0.837452,
#    'val_mse': 1.11891},
#   {'epoch': 1,
#    'loss': 0.772449,
#    'rate': 0.772449,
#    'mse': 1.11801,
#    'val_loss': 0.645036,
#    'val_rate': 0.645036,
#    'val_mse': 1.11297},
#   {'epoch': 2,
#    'loss': 0.589515,
#    'rate': 0.589515,
#    'mse': 1.11475,
#    'val_loss': 0.487694,
#    'val_rate': 0.487694,
#    'val_mse': 1.11031},
#   {'epoch': 3,
#    'loss': 0.479885,
#    'rate': 0.479885,
#    'mse': 1.1121,
#    'val_loss': 0.487608,
#    'val_rate': 0.487608,
#    'val_mse': 1.11826},
#   {'epoch': 4,
#    'loss': 0.397085,
#    'rate': 0.397085,
#    'mse': 1.10967,
#    'val_loss': 0.355602,
#    'val_rate': 0.355602,
#    'val_mse': 1.10778},
#   {'epoch': 5,
#    'loss': 0.337445,
#    'rate': 0.337445,
#    'mse': 1.10767,
#    'val_loss': 0.30193,
#    'val_rate': 0.30193,
#    'val_mse': 1.10364},
#   {'epoch': 6,
#    'loss': 0.297418,
#    'rate': 0.297418,
#    'mse': 1.10576,
#    'val_loss': 0.278344,
#    'val_rate': 0.278344,
#    'val_mse': 1.10928},
#   {'epoch': 7,
#    'loss': 0.265309,
#    'rate': 0.265309,
#    'mse': 1.10424,
#    'val_loss': 0.256587,
#    'val_rate': 0.256587,
#    'val_mse': 1.10481},
#   {'epoch': 8,
#    'loss': 0.242301,
#    'rate': 0.242301,
#    'mse': 1.10271,
#    'val_loss': 0.22407,
#    'val_rate': 0.22407,
#    'val_mse': 1.10109},
#   {'epoch': 9,
#    'loss': 0.225876,
#    'rate': 0.225876,
#    'mse': 1.10129,
#    'val_loss': 0.225284,
#    'val_rate': 0.225284,
#    'val_mse': 1.10436},
#   {'epoch': 10,
#    'loss': 0.0480013,
#    'rate': 0.0480013,
#    'mse': 1.10075,
#    'val_loss': 0.0500527,
#    'val_rate': 0.0500527,
#    'val_mse': 1.10234},
#   {'epoch': 11,
#    'loss': 0.0480574,
#    'rate': 0.0480574,
#    'mse': 1.10064,
#    'val_loss': 0.0502375,
#    'val_rate': 0.0502375,
#    'val_mse': 1.10277},
#   {'epoch': 12,
#    'loss': 0.0479288,
#    'rate': 0.0479288,
#    'mse': 1.10048,
#    'val_loss': 0.0560601,
#    'val_rate': 0.0560601,
#    'val_mse': 1.10397},
#   {'epoch': 13,
#    'loss': 0.047504,
#    'rate': 0.047504,
#    'mse': 1.10058,
#    'val_loss': 0.0456209,
#    'val_rate': 0.0456209,
#    'val_mse': 1.10025},
#   {'epoch': 14,
#    'loss': 0.0476392,
#    'rate': 0.0476392,
#    'mse': 1.10043,
#    'val_loss': 0.0432706,
#    'val_rate': 0.0432706,
#    'val_mse': 1.1002},
#   {'epoch': 15,
#    'loss': 0.0111389,
#    'rate': 0.0111389,
#    'mse': 1.10046,
#    'val_loss': 0.0102232,
#    'val_rate': 0.0102232,
#    'val_mse': 1.1001},
#   {'epoch': 16,
#    'loss': 0.00983365,
#    'rate': 0.00983365,
#    'mse': 1.10044,
#    'val_loss': 0.00996704,
#    'val_rate': 0.00996704,
#    'val_mse': 1.10104},
#   {'epoch': 17,
#    'loss': 0.00990622,
#    'rate': 0.00990622,
#    'mse': 1.10049,
#    'val_loss': 0.0100589,
#    'val_rate': 0.0100589,
#    'val_mse': 1.1009},
#   {'epoch': 18,
#    'loss': 0.00341514,
#    'rate': 0.00341514,
#    'mse': 1.10044,
#    'val_loss': 0.00225109,
#    'val_rate': 0.00225109,
#    'val_mse': 1.10084},
#   {'epoch': 19,
#    'loss': 0.00224427,
#    'rate': 0.00224427,
#    'mse': 1.10041,
#    'val_loss': 0.00234379,
#    'val_rate': 0.00234379,
#    'val_mse': 1.10044}],
#  1e-14: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837377,
#    'val_rate': 0.837377,
#    'val_mse': 1.11879},
#   {'epoch': 1,
#    'loss': 0.772493,
#    'rate': 0.772493,
#    'mse': 1.11801,
#    'val_loss': 0.644277,
#    'val_rate': 0.644277,
#    'val_mse': 1.11305},
#   {'epoch': 2,
#    'loss': 0.589464,
#    'rate': 0.589464,
#    'mse': 1.11475,
#    'val_loss': 0.487057,
#    'val_rate': 0.487057,
#    'val_mse': 1.11042},
#   {'epoch': 3,
#    'loss': 0.479957,
#    'rate': 0.479957,
#    'mse': 1.1121,
#    'val_loss': 0.486784,
#    'val_rate': 0.486784,
#    'val_mse': 1.11822},
#   {'epoch': 4,
#    'loss': 0.397086,
#    'rate': 0.397086,
#    'mse': 1.10967,
#    'val_loss': 0.355708,
#    'val_rate': 0.355708,
#    'val_mse': 1.10774},
#   {'epoch': 5,
#    'loss': 0.337449,
#    'rate': 0.337449,
#    'mse': 1.10767,
#    'val_loss': 0.304041,
#    'val_rate': 0.304041,
#    'val_mse': 1.1034},
#   {'epoch': 6,
#    'loss': 0.297351,
#    'rate': 0.297351,
#    'mse': 1.10576,
#    'val_loss': 0.280067,
#    'val_rate': 0.280067,
#    'val_mse': 1.10947},
#   {'epoch': 7,
#    'loss': 0.265474,
#    'rate': 0.265474,
#    'mse': 1.10424,
#    'val_loss': 0.254434,
#    'val_rate': 0.254434,
#    'val_mse': 1.10442},
#   {'epoch': 8,
#    'loss': 0.242234,
#    'rate': 0.242234,
#    'mse': 1.10271,
#    'val_loss': 0.224203,
#    'val_rate': 0.224203,
#    'val_mse': 1.10099},
#   {'epoch': 9,
#    'loss': 0.225911,
#    'rate': 0.225911,
#    'mse': 1.10128,
#    'val_loss': 0.224706,
#    'val_rate': 0.224706,
#    'val_mse': 1.10429},
#   {'epoch': 10,
#    'loss': 0.0479909,
#    'rate': 0.0479909,
#    'mse': 1.10075,
#    'val_loss': 0.0505443,
#    'val_rate': 0.0505443,
#    'val_mse': 1.10247},
#   {'epoch': 11,
#    'loss': 0.0480305,
#    'rate': 0.0480305,
#    'mse': 1.10064,
#    'val_loss': 0.0506706,
#    'val_rate': 0.0506706,
#    'val_mse': 1.10287},
#   {'epoch': 12,
#    'loss': 0.0479354,
#    'rate': 0.0479354,
#    'mse': 1.10048,
#    'val_loss': 0.0557398,
#    'val_rate': 0.0557398,
#    'val_mse': 1.10392},
#   {'epoch': 13,
#    'loss': 0.0475102,
#    'rate': 0.0475102,
#    'mse': 1.10058,
#    'val_loss': 0.0456146,
#    'val_rate': 0.0456146,
#    'val_mse': 1.10014},
#   {'epoch': 14,
#    'loss': 0.0476187,
#    'rate': 0.0476187,
#    'mse': 1.10043,
#    'val_loss': 0.0432818,
#    'val_rate': 0.0432818,
#    'val_mse': 1.10016},
#   {'epoch': 15,
#    'loss': 0.011131,
#    'rate': 0.011131,
#    'mse': 1.10046,
#    'val_loss': 0.0101976,
#    'val_rate': 0.0101976,
#    'val_mse': 1.10011},
#   {'epoch': 16,
#    'loss': 0.00982992,
#    'rate': 0.00982992,
#    'mse': 1.10044,
#    'val_loss': 0.0099902,
#    'val_rate': 0.0099902,
#    'val_mse': 1.10109},
#   {'epoch': 17,
#    'loss': 0.00990936,
#    'rate': 0.00990936,
#    'mse': 1.10049,
#    'val_loss': 0.0101941,
#    'val_rate': 0.0101941,
#    'val_mse': 1.10098},
#   {'epoch': 18,
#    'loss': 0.00341226,
#    'rate': 0.00341226,
#    'mse': 1.10044,
#    'val_loss': 0.0022421,
#    'val_rate': 0.0022421,
#    'val_mse': 1.10086},
#   {'epoch': 19,
#    'loss': 0.00223801,
#    'rate': 0.00223801,
#    'mse': 1.10041,
#    'val_loss': 0.00233544,
#    'val_rate': 0.00233544,
#    'val_mse': 1.10047}],
#  3e-14: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837341,
#    'val_rate': 0.837341,
#    'val_mse': 1.11882},
#   {'epoch': 1,
#    'loss': 0.772476,
#    'rate': 0.772476,
#    'mse': 1.11801,
#    'val_loss': 0.645514,
#    'val_rate': 0.645514,
#    'val_mse': 1.11293},
#   {'epoch': 2,
#    'loss': 0.589592,
#    'rate': 0.589592,
#    'mse': 1.11475,
#    'val_loss': 0.490016,
#    'val_rate': 0.490016,
#    'val_mse': 1.10994},
#   {'epoch': 3,
#    'loss': 0.479837,
#    'rate': 0.479837,
#    'mse': 1.1121,
#    'val_loss': 0.486043,
#    'val_rate': 0.486043,
#    'val_mse': 1.11818},
#   {'epoch': 4,
#    'loss': 0.397145,
#    'rate': 0.397145,
#    'mse': 1.10967,
#    'val_loss': 0.355099,
#    'val_rate': 0.355099,
#    'val_mse': 1.10795},
#   {'epoch': 5,
#    'loss': 0.337367,
#    'rate': 0.337367,
#    'mse': 1.10767,
#    'val_loss': 0.301195,
#    'val_rate': 0.301195,
#    'val_mse': 1.10374},
#   {'epoch': 6,
#    'loss': 0.297382,
#    'rate': 0.297382,
#    'mse': 1.10576,
#    'val_loss': 0.278967,
#    'val_rate': 0.278967,
#    'val_mse': 1.10935},
#   {'epoch': 7,
#    'loss': 0.265475,
#    'rate': 0.265475,
#    'mse': 1.10424,
#    'val_loss': 0.254266,
#    'val_rate': 0.254266,
#    'val_mse': 1.10439},
#   {'epoch': 8,
#    'loss': 0.242282,
#    'rate': 0.242282,
#    'mse': 1.10271,
#    'val_loss': 0.223901,
#    'val_rate': 0.223901,
#    'val_mse': 1.1012},
#   {'epoch': 9,
#    'loss': 0.225823,
#    'rate': 0.225823,
#    'mse': 1.10128,
#    'val_loss': 0.224444,
#    'val_rate': 0.224444,
#    'val_mse': 1.10424},
#   {'epoch': 10,
#    'loss': 0.0480149,
#    'rate': 0.0480149,
#    'mse': 1.10075,
#    'val_loss': 0.0503828,
#    'val_rate': 0.0503828,
#    'val_mse': 1.10243},
#   {'epoch': 11,
#    'loss': 0.0480516,
#    'rate': 0.0480516,
#    'mse': 1.10065,
#    'val_loss': 0.0503323,
#    'val_rate': 0.0503323,
#    'val_mse': 1.1028},
#   {'epoch': 12,
#    'loss': 0.0479421,
#    'rate': 0.0479421,
#    'mse': 1.10048,
#    'val_loss': 0.0554309,
#    'val_rate': 0.0554309,
#    'val_mse': 1.10388},
#   {'epoch': 13,
#    'loss': 0.0474955,
#    'rate': 0.0474955,
#    'mse': 1.10058,
#    'val_loss': 0.0455877,
#    'val_rate': 0.0455877,
#    'val_mse': 1.10023},
#   {'epoch': 14,
#    'loss': 0.0476319,
#    'rate': 0.0476319,
#    'mse': 1.10043,
#    'val_loss': 0.0434072,
#    'val_rate': 0.0434072,
#    'val_mse': 1.10011},
#   {'epoch': 15,
#    'loss': 0.0111279,
#    'rate': 0.0111279,
#    'mse': 1.10047,
#    'val_loss': 0.010248,
#    'val_rate': 0.010248,
#    'val_mse': 1.10005},
#   {'epoch': 16,
#    'loss': 0.00982486,
#    'rate': 0.00982486,
#    'mse': 1.10044,
#    'val_loss': 0.0100026,
#    'val_rate': 0.0100026,
#    'val_mse': 1.10108},
#   {'epoch': 17,
#    'loss': 0.00989564,
#    'rate': 0.00989564,
#    'mse': 1.10049,
#    'val_loss': 0.0101142,
#    'val_rate': 0.0101142,
#    'val_mse': 1.10094},
#   {'epoch': 18,
#    'loss': 0.00342224,
#    'rate': 0.00342224,
#    'mse': 1.10044,
#    'val_loss': 0.00226448,
#    'val_rate': 0.00226448,
#    'val_mse': 1.10084},
#   {'epoch': 19,
#    'loss': 0.00223455,
#    'rate': 0.00223455,
#    'mse': 1.10041,
#    'val_loss': 0.00234777,
#    'val_rate': 0.00234777,
#    'val_mse': 1.10043}],
#  1e-13: [{'epoch': 0,
#    'loss': 3.63893,
#    'rate': 3.63893,
#    'mse': 1.12019,
#    'val_loss': 0.837484,
#    'val_rate': 0.837484,
#    'val_mse': 1.1189},
#   {'epoch': 1,
#    'loss': 0.772466,
#    'rate': 0.772466,
#    'mse': 1.11801,
#    'val_loss': 0.644836,
#    'val_rate': 0.644836,
#    'val_mse': 1.11299},
#   {'epoch': 2,
#    'loss': 0.589483,
#    'rate': 0.589483,
#    'mse': 1.11475,
#    'val_loss': 0.486159,
#    'val_rate': 0.486159,
#    'val_mse': 1.11059},
#   {'epoch': 3,
#    'loss': 0.479889,
#    'rate': 0.479889,
#    'mse': 1.1121,
#    'val_loss': 0.486679,
#    'val_rate': 0.486679,
#    'val_mse': 1.11821},
#   {'epoch': 4,
#    'loss': 0.397092,
#    'rate': 0.397092,
#    'mse': 1.10967,
#    'val_loss': 0.356107,
#    'val_rate': 0.356107,
#    'val_mse': 1.10763},
#   {'epoch': 5,
#    'loss': 0.337457,
#    'rate': 0.337457,
#    'mse': 1.10767,
#    'val_loss': 0.304506,
#    'val_rate': 0.304506,
#    'val_mse': 1.10334},
#   {'epoch': 6,
#    'loss': 0.29734,
#    'rate': 0.29734,
#    'mse': 1.10576,
#    'val_loss': 0.277866,
#    'val_rate': 0.277866,
#    'val_mse': 1.10923},
#   {'epoch': 7,
#    'loss': 0.265497,
#    'rate': 0.265497,
#    'mse': 1.10424,
#    'val_loss': 0.255113,
#    'val_rate': 0.255113,
#    'val_mse': 1.10457},
#   {'epoch': 8,
#    'loss': 0.242316,
#    'rate': 0.242316,
#    'mse': 1.10271,
#    'val_loss': 0.223764,
#    'val_rate': 0.223764,
#    'val_mse': 1.10123},
#   {'epoch': 9,
#    'loss': 0.225782,
#    'rate': 0.225782,
#    'mse': 1.10128,
#    'val_loss': 0.224254,
#    'val_rate': 0.224254,
#    'val_mse': 1.10422},
#   {'epoch': 10,
#    'loss': 0.0480054,
#    'rate': 0.0480054,
#    'mse': 1.10075,
#    'val_loss': 0.0504232,
#    'val_rate': 0.0504232,
#    'val_mse': 1.10244},
#   {'epoch': 11,
#    'loss': 0.0480436,
#    'rate': 0.0480436,
#    'mse': 1.10064,
#    'val_loss': 0.0511084,
#    'val_rate': 0.0511084,
#    'val_mse': 1.10297},
#   {'epoch': 12,
#    'loss': 0.0479177,
#    'rate': 0.0479177,
#    'mse': 1.10048,
#    'val_loss': 0.055631,
#    'val_rate': 0.055631,
#    'val_mse': 1.10392},
#   {'epoch': 13,
#    'loss': 0.0475076,
#    'rate': 0.0475076,
#    'mse': 1.10058,
#    'val_loss': 0.0455716,
#    'val_rate': 0.0455716,
#    'val_mse': 1.10012},
#   {'epoch': 14,
#    'loss': 0.0476222,
#    'rate': 0.0476222,
#    'mse': 1.10043,
#    'val_loss': 0.0433489,
#    'val_rate': 0.0433489,
#    'val_mse': 1.10018},
#   {'epoch': 15,
#    'loss': 0.0111371,
#    'rate': 0.0111371,
#    'mse': 1.10046,
#    'val_loss': 0.0102257,
#    'val_rate': 0.0102257,
#    'val_mse': 1.10013},
#   {'epoch': 16,
#    'loss': 0.00983048,
#    'rate': 0.00983048,
#    'mse': 1.10044,
#    'val_loss': 0.00989598,
#    'val_rate': 0.00989598,
#    'val_mse': 1.10098},
#   {'epoch': 17,
#    'loss': 0.00990739,
#    'rate': 0.00990739,
#    'mse': 1.10049,
#    'val_loss': 0.0101045,
#    'val_rate': 0.0101045,
#    'val_mse': 1.10092},
#   {'epoch': 18,
#    'loss': 0.00342494,
#    'rate': 0.00342494,
#    'mse': 1.10044,
#    'val_loss': 0.00226688,
#    'val_rate': 0.00226688,
#    'val_mse': 1.10083},
#   {'epoch': 19,
#    'loss': 0.00224062,
#    'rate': 0.00224062,
#    'mse': 1.10041,
#    'val_loss': 0.00242377,
#    'val_rate': 0.00242377,
#    'val_mse': 1.10051}],
#  3e-13: [{'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 1.12019,
#    'val_loss': 0.837412,
#    'val_rate': 0.837412,
#    'val_mse': 1.11884},
#   {'epoch': 1,
#    'loss': 0.772437,
#    'rate': 0.772437,
#    'mse': 1.11801,
#    'val_loss': 0.644766,
#    'val_rate': 0.644766,
#    'val_mse': 1.113},
#   {'epoch': 2,
#    'loss': 0.589553,
#    'rate': 0.589553,
#    'mse': 1.11475,
#    'val_loss': 0.488157,
#    'val_rate': 0.488157,
#    'val_mse': 1.11024},
#   {'epoch': 3,
#    'loss': 0.479844,
#    'rate': 0.479844,
#    'mse': 1.1121,
#    'val_loss': 0.492937,
#    'val_rate': 0.492937,
#    'val_mse': 1.11855},
#   {'epoch': 4,
#    'loss': 0.397145,
#    'rate': 0.397145,
#    'mse': 1.10967,
#    'val_loss': 0.354756,
#    'val_rate': 0.354756,
#    'val_mse': 1.10809},
#   {'epoch': 5,
#    'loss': 0.33739,
#    'rate': 0.33739,
#    'mse': 1.10767,
#    'val_loss': 0.301613,
#    'val_rate': 0.301613,
#    'val_mse': 1.10368},
#   {'epoch': 6,
#    'loss': 0.297292,
#    'rate': 0.297292,
#    'mse': 1.10576,
#    'val_loss': 0.279128,
#    'val_rate': 0.279128,
#    'val_mse': 1.10937},
#   {'epoch': 7,
#    'loss': 0.26526,
#    'rate': 0.26526,
#    'mse': 1.10424,
#    'val_loss': 0.25566,
#    'val_rate': 0.25566,
#    'val_mse': 1.10466},
#   {'epoch': 8,
#    'loss': 0.242326,
#    'rate': 0.242326,
#    'mse': 1.10271,
#    'val_loss': 0.223791,
#    'val_rate': 0.223791,
#    'val_mse': 1.10125},
#   {'epoch': 9,
#    'loss': 0.225807,
#    'rate': 0.225807,
#    'mse': 1.10128,
#    'val_loss': 0.223242,
#    'val_rate': 0.223242,
#    'val_mse': 1.1041},
#   {'epoch': 10,
#    'loss': 0.0480109,
#    'rate': 0.0480109,
#    'mse': 1.10075,
#    'val_loss': 0.0499485,
#    'val_rate': 0.0499485,
#    'val_mse': 1.10229},
#   {'epoch': 11,
#    'loss': 0.0480295,
#    'rate': 0.0480295,
#    'mse': 1.10064,
#    'val_loss': 0.0506599,
#    'val_rate': 0.0506599,
#    'val_mse': 1.10287},
#   {'epoch': 12,
#    'loss': 0.0479359,
#    'rate': 0.0479359,
#    'mse': 1.10048,
#    'val_loss': 0.0561345,
#    'val_rate': 0.0561345,
#    'val_mse': 1.10399},
#   {'epoch': 13,
#    'loss': 0.0475032,
#    'rate': 0.0475032,
#    'mse': 1.10058,
#    'val_loss': 0.0456178,
#    'val_rate': 0.0456178,
#    'val_mse': 1.10027},
#   {'epoch': 14,
#    'loss': 0.0475924,
#    'rate': 0.0475924,
#    'mse': 1.10043,
#    'val_loss': 0.0433797,
#    'val_rate': 0.0433797,
#    'val_mse': 1.10015},
#   {'epoch': 15,
#    'loss': 0.0111298,
#    'rate': 0.0111298,
#    'mse': 1.10046,
#    'val_loss': 0.010239,
#    'val_rate': 0.010239,
#    'val_mse': 1.10011},
#   {'epoch': 16,
#    'loss': 0.00983228,
#    'rate': 0.00983228,
#    'mse': 1.10044,
#    'val_loss': 0.00996207,
#    'val_rate': 0.00996207,
#    'val_mse': 1.10106},
#   {'epoch': 17,
#    'loss': 0.00992208,
#    'rate': 0.00992208,
#    'mse': 1.10049,
#    'val_loss': 0.00992454,
#    'val_rate': 0.00992454,
#    'val_mse': 1.10081},
#   {'epoch': 18,
#    'loss': 0.00342006,
#    'rate': 0.00342006,
#    'mse': 1.10044,
#    'val_loss': 0.00224977,
#    'val_rate': 0.00224977,
#    'val_mse': 1.10085},
#   {'epoch': 19,
#    'loss': 0.00224231,
#    'rate': 0.00224231,
#    'mse': 1.10041,
#    'val_loss': 0.00229824,
#    'val_rate': 0.00229824,
#    'val_mse': 1.10038}],
#  1e-12: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 1,
#    'loss': 0.772461,
#    'rate': 0.772461,
#    'mse': 1.11801,
#    'val_loss': 0.644356,
#    'val_rate': 0.644356,
#    'val_mse': 1.11305},
#   {'epoch': 2,
#    'loss': 0.589569,
#    'rate': 0.589569,
#    'mse': 1.11475,
#    'val_loss': 0.488991,
#    'val_rate': 0.488991,
#    'val_mse': 1.1101},
#   {'epoch': 3,
#    'loss': 0.479818,
#    'rate': 0.479818,
#    'mse': 1.1121,
#    'val_loss': 0.487102,
#    'val_rate': 0.487102,
#    'val_mse': 1.11823},
#   {'epoch': 4,
#    'loss': 0.397107,
#    'rate': 0.397107,
#    'mse': 1.10967,
#    'val_loss': 0.355268,
#    'val_rate': 0.355268,
#    'val_mse': 1.10788},
#   {'epoch': 5,
#    'loss': 0.337396,
#    'rate': 0.337396,
#    'mse': 1.10767,
#    'val_loss': 0.301571,
#    'val_rate': 0.301571,
#    'val_mse': 1.10368},
#   {'epoch': 6,
#    'loss': 0.297418,
#    'rate': 0.297418,
#    'mse': 1.10576,
#    'val_loss': 0.277629,
#    'val_rate': 0.277629,
#    'val_mse': 1.1092},
#   {'epoch': 7,
#    'loss': 0.26547,
#    'rate': 0.26547,
#    'mse': 1.10424,
#    'val_loss': 0.255861,
#    'val_rate': 0.255861,
#    'val_mse': 1.10469},
#   {'epoch': 8,
#    'loss': 0.242279,
#    'rate': 0.242279,
#    'mse': 1.10271,
#    'val_loss': 0.224275,
#    'val_rate': 0.224275,
#    'val_mse': 1.10095},
#   {'epoch': 9,
#    'loss': 0.225859,
#    'rate': 0.225859,
#    'mse': 1.10127,
#    'val_loss': 0.22451,
#    'val_rate': 0.22451,
#    'val_mse': 1.10424},
#   {'epoch': 10,
#    'loss': 0.0480324,
#    'rate': 0.0480324,
#    'mse': 1.10074,
#    'val_loss': 0.0504139,
#    'val_rate': 0.0504139,
#    'val_mse': 1.10242},
#   {'epoch': 11,
#    'loss': 0.0480446,
#    'rate': 0.0480446,
#    'mse': 1.10063,
#    'val_loss': 0.050649,
#    'val_rate': 0.050649,
#    'val_mse': 1.10286},
#   {'epoch': 12,
#    'loss': 0.0479112,
#    'rate': 0.0479112,
#    'mse': 1.10047,
#    'val_loss': 0.0561354,
#    'val_rate': 0.0561354,
#    'val_mse': 1.10398},
#   {'epoch': 13,
#    'loss': 0.0475039,
#    'rate': 0.0475039,
#    'mse': 1.10057,
#    'val_loss': 0.0455943,
#    'val_rate': 0.0455943,
#    'val_mse': 1.10019},
#   {'epoch': 14,
#    'loss': 0.0476346,
#    'rate': 0.0476346,
#    'mse': 1.10042,
#    'val_loss': 0.0433191,
#    'val_rate': 0.0433191,
#    'val_mse': 1.10015},
#   {'epoch': 15,
#    'loss': 0.0111326,
#    'rate': 0.0111326,
#    'mse': 1.10045,
#    'val_loss': 0.0102483,
#    'val_rate': 0.0102483,
#    'val_mse': 1.10007},
#   {'epoch': 16,
#    'loss': 0.00983327,
#    'rate': 0.00983327,
#    'mse': 1.10043,
#    'val_loss': 0.0100199,
#    'val_rate': 0.0100199,
#    'val_mse': 1.10111},
#   {'epoch': 17,
#    'loss': 0.00990697,
#    'rate': 0.00990697,
#    'mse': 1.10048,
#    'val_loss': 0.0100869,
#    'val_rate': 0.0100869,
#    'val_mse': 1.10091},
#   {'epoch': 18,
#    'loss': 0.00341598,
#    'rate': 0.00341598,
#    'mse': 1.10043,
#    'val_loss': 0.00227739,
#    'val_rate': 0.00227739,
#    'val_mse': 1.10086},
#   {'epoch': 19,
#    'loss': 0.00224554,
#    'rate': 0.00224554,
#    'mse': 1.1004,
#    'val_loss': 0.00239829,
#    'val_rate': 0.00239829,
#    'val_mse': 1.10052}],
#  3e-12: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 1,
#    'loss': 0.77247,
#    'rate': 0.77247,
#    'mse': 1.118,
#    'val_loss': 0.644285,
#    'val_rate': 0.644285,
#    'val_mse': 1.11304},
#   {'epoch': 2,
#    'loss': 0.589531,
#    'rate': 0.589531,
#    'mse': 1.11473,
#    'val_loss': 0.489801,
#    'val_rate': 0.489801,
#    'val_mse': 1.10995},
#   {'epoch': 3,
#    'loss': 0.479843,
#    'rate': 0.479843,
#    'mse': 1.11207,
#    'val_loss': 0.4885,
#    'val_rate': 0.4885,
#    'val_mse': 1.11828},
#   {'epoch': 4,
#    'loss': 0.397131,
#    'rate': 0.397131,
#    'mse': 1.10964,
#    'val_loss': 0.355159,
#    'val_rate': 0.355159,
#    'val_mse': 1.10789},
#   {'epoch': 5,
#    'loss': 0.337429,
#    'rate': 0.337429,
#    'mse': 1.10762,
#    'val_loss': 0.303286,
#    'val_rate': 0.303286,
#    'val_mse': 1.10342},
#   {'epoch': 6,
#    'loss': 0.297397,
#    'rate': 0.297397,
#    'mse': 1.1057,
#    'val_loss': 0.27841,
#    'val_rate': 0.27841,
#    'val_mse': 1.10923},
#   {'epoch': 7,
#    'loss': 0.265545,
#    'rate': 0.265545,
#    'mse': 1.10418,
#    'val_loss': 0.254978,
#    'val_rate': 0.254978,
#    'val_mse': 1.10445},
#   {'epoch': 8,
#    'loss': 0.242228,
#    'rate': 0.242228,
#    'mse': 1.10264,
#    'val_loss': 0.224233,
#    'val_rate': 0.224233,
#    'val_mse': 1.1009},
#   {'epoch': 9,
#    'loss': 0.225878,
#    'rate': 0.225878,
#    'mse': 1.1012,
#    'val_loss': 0.224168,
#    'val_rate': 0.224168,
#    'val_mse': 1.10412},
#   {'epoch': 10,
#    'loss': 0.0479989,
#    'rate': 0.0479989,
#    'mse': 1.10066,
#    'val_loss': 0.0504903,
#    'val_rate': 0.0504903,
#    'val_mse': 1.10235},
#   {'epoch': 11,
#    'loss': 0.0480531,
#    'rate': 0.0480531,
#    'mse': 1.10055,
#    'val_loss': 0.0502659,
#    'val_rate': 0.0502659,
#    'val_mse': 1.10269},
#   {'epoch': 12,
#    'loss': 0.047937,
#    'rate': 0.047937,
#    'mse': 1.10039,
#    'val_loss': 0.0563413,
#    'val_rate': 0.0563413,
#    'val_mse': 1.10392},
#   {'epoch': 13,
#    'loss': 0.047497,
#    'rate': 0.047497,
#    'mse': 1.10049,
#    'val_loss': 0.0455614,
#    'val_rate': 0.0455614,
#    'val_mse': 1.10001},
#   {'epoch': 14,
#    'loss': 0.0476037,
#    'rate': 0.0476037,
#    'mse': 1.10034,
#    'val_loss': 0.0433169,
#    'val_rate': 0.0433169,
#    'val_mse': 1.10006},
#   {'epoch': 15,
#    'loss': 0.0111377,
#    'rate': 0.0111377,
#    'mse': 1.10037,
#    'val_loss': 0.0102338,
#    'val_rate': 0.0102338,
#    'val_mse': 1.09998},
#   {'epoch': 16,
#    'loss': 0.00983139,
#    'rate': 0.00983139,
#    'mse': 1.10035,
#    'val_loss': 0.00998736,
#    'val_rate': 0.00998736,
#    'val_mse': 1.10098},
#   {'epoch': 17,
#    'loss': 0.00991034,
#    'rate': 0.00991034,
#    'mse': 1.10039,
#    'val_loss': 0.0101488,
#    'val_rate': 0.0101488,
#    'val_mse': 1.10086},
#   {'epoch': 18,
#    'loss': 0.00341497,
#    'rate': 0.00341497,
#    'mse': 1.10035,
#    'val_loss': 0.00224568,
#    'val_rate': 0.00224568,
#    'val_mse': 1.10076},
#   {'epoch': 19,
#    'loss': 0.00224273,
#    'rate': 0.00224273,
#    'mse': 1.10032,
#    'val_loss': 0.00238972,
#    'val_rate': 0.00238972,
#    'val_mse': 1.10042}],
#  1e-11: [{'epoch': 0,
#    'loss': 3.63893,
#    'rate': 3.63893,
#    'mse': 1.12017,
#    'val_loss': 0.837389,
#    'val_rate': 0.837389,
#    'val_mse': 1.11879},
#   {'epoch': 1,
#    'loss': 0.772463,
#    'rate': 0.772463,
#    'mse': 1.1179,
#    'val_loss': 0.645159,
#    'val_rate': 0.645159,
#    'val_mse': 1.1128},
#   {'epoch': 2,
#    'loss': 0.58946,
#    'rate': 0.58946,
#    'mse': 1.11454,
#    'val_loss': 0.485793,
#    'val_rate': 0.485793,
#    'val_mse': 1.1104},
#   {'epoch': 3,
#    'loss': 0.479928,
#    'rate': 0.479928,
#    'mse': 1.11179,
#    'val_loss': 0.488986,
#    'val_rate': 0.488986,
#    'val_mse': 1.11797},
#   {'epoch': 4,
#    'loss': 0.397159,
#    'rate': 0.397159,
#    'mse': 1.10925,
#    'val_loss': 0.35542,
#    'val_rate': 0.35542,
#    'val_mse': 1.10736},
#   {'epoch': 5,
#    'loss': 0.337408,
#    'rate': 0.337408,
#    'mse': 1.10714,
#    'val_loss': 0.302199,
#    'val_rate': 0.302199,
#    'val_mse': 1.10303},
#   {'epoch': 6,
#    'loss': 0.297266,
#    'rate': 0.297266,
#    'mse': 1.10513,
#    'val_loss': 0.279453,
#    'val_rate': 0.279453,
#    'val_mse': 1.10872},
#   {'epoch': 7,
#    'loss': 0.265385,
#    'rate': 0.265385,
#    'mse': 1.10351,
#    'val_loss': 0.255509,
#    'val_rate': 0.255509,
#    'val_mse': 1.10383},
#   {'epoch': 8,
#    'loss': 0.24224,
#    'rate': 0.24224,
#    'mse': 1.10187,
#    'val_loss': 0.223969,
#    'val_rate': 0.223969,
#    'val_mse': 1.1002},
#   {'epoch': 9,
#    'loss': 0.225828,
#    'rate': 0.225828,
#    'mse': 1.10034,
#    'val_loss': 0.222031,
#    'val_rate': 0.222031,
#    'val_mse': 1.10293},
#   {'epoch': 10,
#    'loss': 0.0480053,
#    'rate': 0.0480053,
#    'mse': 1.09975,
#    'val_loss': 0.0504611,
#    'val_rate': 0.0504611,
#    'val_mse': 1.10146},
#   {'epoch': 11,
#    'loss': 0.0480438,
#    'rate': 0.0480438,
#    'mse': 1.09965,
#    'val_loss': 0.0509947,
#    'val_rate': 0.0509947,
#    'val_mse': 1.10194},
#   {'epoch': 12,
#    'loss': 0.0479278,
#    'rate': 0.0479278,
#    'mse': 1.09948,
#    'val_loss': 0.0552296,
#    'val_rate': 0.0552296,
#    'val_mse': 1.10285},
#   {'epoch': 13,
#    'loss': 0.047502,
#    'rate': 0.047502,
#    'mse': 1.09958,
#    'val_loss': 0.0456435,
#    'val_rate': 0.0456435,
#    'val_mse': 1.09925},
#   {'epoch': 14,
#    'loss': 0.0476208,
#    'rate': 0.0476208,
#    'mse': 1.09942,
#    'val_loss': 0.0433685,
#    'val_rate': 0.0433685,
#    'val_mse': 1.09909},
#   {'epoch': 15,
#    'loss': 0.011133,
#    'rate': 0.011133,
#    'mse': 1.09945,
#    'val_loss': 0.0102977,
#    'val_rate': 0.0102977,
#    'val_mse': 1.099},
#   {'epoch': 16,
#    'loss': 0.00982618,
#    'rate': 0.00982618,
#    'mse': 1.09943,
#    'val_loss': 0.0100768,
#    'val_rate': 0.0100768,
#    'val_mse': 1.10014},
#   {'epoch': 17,
#    'loss': 0.0098993,
#    'rate': 0.0098993,
#    'mse': 1.09947,
#    'val_loss': 0.0100506,
#    'val_rate': 0.0100506,
#    'val_mse': 1.09988},
#   {'epoch': 18,
#    'loss': 0.00341377,
#    'rate': 0.00341377,
#    'mse': 1.09942,
#    'val_loss': 0.00227201,
#    'val_rate': 0.00227201,
#    'val_mse': 1.09984},
#   {'epoch': 19,
#    'loss': 0.00224481,
#    'rate': 0.00224481,
#    'mse': 1.0994,
#    'val_loss': 0.00232516,
#    'val_rate': 0.00232516,
#    'val_mse': 1.09937}]}

# %%
for l in lmbdas:
    print(len(data_dict[l]))
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20

# %%
for l in lmbdas:
# epoch별 데이터 추출
    data_dict[l] = sorted(data_dict[l], key=lambda x: x['epoch'])
    
    epochs = [entry['epoch'] for entry in data_dict[l]]
    loss = [entry['loss'] for entry in data_dict[l]]
    val_loss = [entry['val_loss'] for entry in data_dict[l]]
    rate = [entry['rate'] for entry in data_dict[l]]
    val_rate = [entry['val_rate'] for entry in data_dict[l]]
    mse = [entry['mse'] for entry in data_dict[l]]
    val_mse = [entry['val_mse'] for entry in data_dict[l]]
# Plot 설정
    plt.figure(figsize=(10, 6))

    # Loss Plot
    plt.subplot(3, 1, 1)
    plt.plot(epochs, loss, label='Training Loss')
    plt.plot(epochs, val_loss, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'lmbdas={l}')
    plt.legend()

    # Rate Plot
    plt.subplot(3, 1, 2)
    plt.plot(epochs, rate, label='Training Rate')
    plt.plot(epochs, val_rate, label='Validation Rate')
    plt.xlabel('Epoch')
    plt.ylabel('Rate')
    plt.title(f'lmbdas={l}')
    plt.legend()
    
    # mse Plot
    plt.subplot(3, 1, 3)
    plt.plot(epochs, mse, label='Training Mse')
    plt.plot(epochs, val_mse, label='Validation Mse')
    plt.xlabel('Epoch')
    plt.ylabel('Mse')
    plt.title(f'lmbdas={l}')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
data_dict
# Out:
# {0: [{'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 0.00822445,
#    'val_loss': 0.837444,
#    'val_rate': 0.837444,
#    'val_mse': 0.000441118},
#   {'epoch': 0,
#    'loss': 3.63896,
#    'rate': 3.63896,
#    'mse': 0.0022832,
#    'val_loss': 0.837383,
#    'val_rate': 0.837383,
#    'val_mse': 0.000413006},
#   {'epoch': 0,
#    'loss': 3.63898,
#    'rate': 3.63894,
#    'mse': 0.00109973,
#    'val_loss': 0.837351,
#    'val_rate': 0.837338,
#    'val_mse': 0.000410979},
#   {'epoch': 0,
#    'loss': 3.63906,
#    'rate': 3.63896,
#    'mse': 0.00104805,
#    'val_loss': 0.837524,
#    'val_rate': 0.837483,
#    'val_mse': 0.000410968},
#   {'epoch': 0,
#    'loss': 3.63896,
#    'rate': 3.63896,
#    'mse': 0.00155377,
#    'val_loss': 0.837389,
#    'val_rate': 0.837388,
#    'val_mse': 0.000411633},
#   {'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 0.00421479,
#    'val_loss': 0.837479,
#    'val_rate': 0.837479,
#    'val_mse': 0.000418869},
#   {'epoch': 1,
#    'loss': 0.772459,
#    'rate': 0.772459,
#    'mse': 0.000426937,
#    'val_loss': 0.644861,
#    'val_rate': 0.644861,
#    'val_mse': 0.000420923},
#   {'epoch': 1,
#    'loss': 0.772456,
#    'rate': 0.772456,
#    'mse': 0.000411294,
#    'val_loss': 0.645277,
#    'val_rate': 0.645277,
#    'val_mse': 0.000411682},
#   {'epoch': 1,
#    'loss': 0.772489,
#    'rate': 0.772477,
#    'mse': 0.000410127,
#    'val_loss': 0.645818,
#    'val_rate': 0.645805,
#    'val_mse': 0.000410979},
#   {'epoch': 1,
#    'loss': 0.772518,
#    'rate': 0.772478,
#    'mse': 0.000410121,
#    'val_loss': 0.644359,
#    'val_rate': 0.644318,
#    'val_mse': 0.000410978}],
#  1e-20: [{'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 1.12019,
#    'val_loss': 0.837413,
#    'val_rate': 0.837413,
#    'val_mse': 1.1188},
#   {'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 1.12019,
#    'val_loss': 0.837413,
#    'val_rate': 0.837413,
#    'val_mse': 1.1188},
#   {'epoch': 1,
#    'loss': 0.772437,
#    'rate': 0.772437,
#    'mse': 1.11801,
#    'val_loss': 0.644114,
#    'val_rate': 0.644114,
#    'val_mse': 1.11306},
#   {'epoch': 1,
#    'loss': 0.772437,
#    'rate': 0.772437,
#    'mse': 1.11801,
#    'val_loss': 0.644114,
#    'val_rate': 0.644114,
#    'val_mse': 1.11306},
#   {'epoch': 2,
#    'loss': 0.589583,
#    'rate': 0.589583,
#    'mse': 1.11475,
#    'val_loss': 0.489241,
#    'val_rate': 0.489241,
#    'val_mse': 1.11006},
#   {'epoch': 2,
#    'loss': 0.589583,
#    'rate': 0.589583,
#    'mse': 1.11475,
#    'val_loss': 0.489241,
#    'val_rate': 0.489241,
#    'val_mse': 1.11006},
#   {'epoch': 3,
#    'loss': 0.479839,
#    'rate': 0.479839,
#    'mse': 1.1121,
#    'val_loss': 0.488303,
#    'val_rate': 0.488303,
#    'val_mse': 1.1183},
#   {'epoch': 3,
#    'loss': 0.479839,
#    'rate': 0.479839,
#    'mse': 1.1121,
#    'val_loss': 0.488303,
#    'val_rate': 0.488303,
#    'val_mse': 1.1183},
#   {'epoch': 4,
#    'loss': 0.397094,
#    'rate': 0.397094,
#    'mse': 1.10967,
#    'val_loss': 0.355766,
#    'val_rate': 0.355766,
#    'val_mse': 1.10771},
#   {'epoch': 4,
#    'loss': 0.397094,
#    'rate': 0.397094,
#    'mse': 1.10967,
#    'val_loss': 0.355766,
#    'val_rate': 0.355766,
#    'val_mse': 1.10771}],
#  3e-20: [{'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 1.12019,
#    'val_loss': 0.837456,
#    'val_rate': 0.837456,
#    'val_mse': 1.11886},
#   {'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 1.12019,
#    'val_loss': 0.837456,
#    'val_rate': 0.837456,
#    'val_mse': 1.11886},
#   {'epoch': 1,
#    'loss': 0.77247,
#    'rate': 0.77247,
#    'mse': 1.11801,
#    'val_loss': 0.644727,
#    'val_rate': 0.644727,
#    'val_mse': 1.11301},
#   {'epoch': 1,
#    'loss': 0.77247,
#    'rate': 0.77247,
#    'mse': 1.11801,
#    'val_loss': 0.644727,
#    'val_rate': 0.644727,
#    'val_mse': 1.11301},
#   {'epoch': 2,
#    'loss': 0.589445,
#    'rate': 0.589445,
#    'mse': 1.11475,
#    'val_loss': 0.487651,
#    'val_rate': 0.487651,
#    'val_mse': 1.11032},
#   {'epoch': 2,
#    'loss': 0.589445,
#    'rate': 0.589445,
#    'mse': 1.11475,
#    'val_loss': 0.487651,
#    'val_rate': 0.487651,
#    'val_mse': 1.11032},
#   {'epoch': 3,
#    'loss': 0.479879,
#    'rate': 0.479879,
#    'mse': 1.1121,
#    'val_loss': 0.491651,
#    'val_rate': 0.491651,
#    'val_mse': 1.11848},
#   {'epoch': 3,
#    'loss': 0.479879,
#    'rate': 0.479879,
#    'mse': 1.1121,
#    'val_loss': 0.491651,
#    'val_rate': 0.491651,
#    'val_mse': 1.11848},
#   {'epoch': 4,
#    'loss': 0.397147,
#    'rate': 0.397147,
#    'mse': 1.10967,
#    'val_loss': 0.355311,
#    'val_rate': 0.355311,
#    'val_mse': 1.10788},
#   {'epoch': 4,
#    'loss': 0.397147,
#    'rate': 0.397147,
#    'mse': 1.10967,
#    'val_loss': 0.355311,
#    'val_rate': 0.355311,
#    'val_mse': 1.10788}],
#  1e-19: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837366,
#    'val_rate': 0.837366,
#    'val_mse': 1.1188},
#   {'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837366,
#    'val_rate': 0.837366,
#    'val_mse': 1.1188},
#   {'epoch': 1,
#    'loss': 0.772494,
#    'rate': 0.772494,
#    'mse': 1.11801,
#    'val_loss': 0.644924,
#    'val_rate': 0.644924,
#    'val_mse': 1.11298},
#   {'epoch': 1,
#    'loss': 0.772494,
#    'rate': 0.772494,
#    'mse': 1.11801,
#    'val_loss': 0.644924,
#    'val_rate': 0.644924,
#    'val_mse': 1.11298},
#   {'epoch': 2,
#    'loss': 0.589518,
#    'rate': 0.589518,
#    'mse': 1.11475,
#    'val_loss': 0.488877,
#    'val_rate': 0.488877,
#    'val_mse': 1.11012},
#   {'epoch': 2,
#    'loss': 0.589518,
#    'rate': 0.589518,
#    'mse': 1.11475,
#    'val_loss': 0.488877,
#    'val_rate': 0.488877,
#    'val_mse': 1.11012},
#   {'epoch': 3,
#    'loss': 0.479822,
#    'rate': 0.479822,
#    'mse': 1.1121,
#    'val_loss': 0.491455,
#    'val_rate': 0.491455,
#    'val_mse': 1.11847},
#   {'epoch': 3,
#    'loss': 0.479822,
#    'rate': 0.479822,
#    'mse': 1.1121,
#    'val_loss': 0.491455,
#    'val_rate': 0.491455,
#    'val_mse': 1.11847},
#   {'epoch': 4,
#    'loss': 0.397116,
#    'rate': 0.397116,
#    'mse': 1.10967,
#    'val_loss': 0.355628,
#    'val_rate': 0.355628,
#    'val_mse': 1.10776},
#   {'epoch': 4,
#    'loss': 0.397116,
#    'rate': 0.397116,
#    'mse': 1.10967,
#    'val_loss': 0.355628,
#    'val_rate': 0.355628,
#    'val_mse': 1.10776}],
#  3e-19: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 1,
#    'loss': 0.77247,
#    'rate': 0.77247,
#    'mse': 1.11801,
#    'val_loss': 0.644285,
#    'val_rate': 0.644285,
#    'val_mse': 1.11305},
#   {'epoch': 1,
#    'loss': 0.77247,
#    'rate': 0.77247,
#    'mse': 1.11801,
#    'val_loss': 0.644285,
#    'val_rate': 0.644285,
#    'val_mse': 1.11305},
#   {'epoch': 2,
#    'loss': 0.589531,
#    'rate': 0.589531,
#    'mse': 1.11475,
#    'val_loss': 0.489801,
#    'val_rate': 0.489801,
#    'val_mse': 1.10998},
#   {'epoch': 2,
#    'loss': 0.589531,
#    'rate': 0.589531,
#    'mse': 1.11475,
#    'val_loss': 0.489801,
#    'val_rate': 0.489801,
#    'val_mse': 1.10998},
#   {'epoch': 3,
#    'loss': 0.479843,
#    'rate': 0.479843,
#    'mse': 1.1121,
#    'val_loss': 0.4885,
#    'val_rate': 0.4885,
#    'val_mse': 1.11831},
#   {'epoch': 3,
#    'loss': 0.479843,
#    'rate': 0.479843,
#    'mse': 1.1121,
#    'val_loss': 0.4885,
#    'val_rate': 0.4885,
#    'val_mse': 1.11831},
#   {'epoch': 4,
#    'loss': 0.397131,
#    'rate': 0.397131,
#    'mse': 1.10967,
#    'val_loss': 0.355159,
#    'val_rate': 0.355159,
#    'val_mse': 1.10793},
#   {'epoch': 4,
#    'loss': 0.397131,
#    'rate': 0.397131,
#    'mse': 1.10967,
#    'val_loss': 0.355159,
#    'val_rate': 0.355159,
#    'val_mse': 1.10793}],
#  1e-18: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837389,
#    'val_rate': 0.837389,
#    'val_mse': 1.11881},
#   {'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837389,
#    'val_rate': 0.837389,
#    'val_mse': 1.11881},
#   {'epoch': 1,
#    'loss': 0.772451,
#    'rate': 0.772451,
#    'mse': 1.11801,
#    'val_loss': 0.64458,
#    'val_rate': 0.64458,
#    'val_mse': 1.11302},
#   {'epoch': 1,
#    'loss': 0.772451,
#    'rate': 0.772451,
#    'mse': 1.11801,
#    'val_loss': 0.64458,
#    'val_rate': 0.64458,
#    'val_mse': 1.11302},
#   {'epoch': 2,
#    'loss': 0.589459,
#    'rate': 0.589459,
#    'mse': 1.11475,
#    'val_loss': 0.486147,
#    'val_rate': 0.486147,
#    'val_mse': 1.11059},
#   {'epoch': 2,
#    'loss': 0.589459,
#    'rate': 0.589459,
#    'mse': 1.11475,
#    'val_loss': 0.486147,
#    'val_rate': 0.486147,
#    'val_mse': 1.11059},
#   {'epoch': 3,
#    'loss': 0.479916,
#    'rate': 0.479916,
#    'mse': 1.1121,
#    'val_loss': 0.488291,
#    'val_rate': 0.488291,
#    'val_mse': 1.1183},
#   {'epoch': 3,
#    'loss': 0.479916,
#    'rate': 0.479916,
#    'mse': 1.1121,
#    'val_loss': 0.488291,
#    'val_rate': 0.488291,
#    'val_mse': 1.1183},
#   {'epoch': 4,
#    'loss': 0.397102,
#    'rate': 0.397102,
#    'mse': 1.10968,
#    'val_loss': 0.355662,
#    'val_rate': 0.355662,
#    'val_mse': 1.10776},
#   {'epoch': 4,
#    'loss': 0.397102,
#    'rate': 0.397102,
#    'mse': 1.10968,
#    'val_loss': 0.355662,
#    'val_rate': 0.355662,
#    'val_mse': 1.10776}],
#  3e-18: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 1,
#    'loss': 0.77247,
#    'rate': 0.77247,
#    'mse': 1.11801,
#    'val_loss': 0.644285,
#    'val_rate': 0.644285,
#    'val_mse': 1.11305},
#   {'epoch': 1,
#    'loss': 0.77247,
#    'rate': 0.77247,
#    'mse': 1.11801,
#    'val_loss': 0.644285,
#    'val_rate': 0.644285,
#    'val_mse': 1.11305},
#   {'epoch': 2,
#    'loss': 0.589531,
#    'rate': 0.589531,
#    'mse': 1.11475,
#    'val_loss': 0.489801,
#    'val_rate': 0.489801,
#    'val_mse': 1.10998},
#   {'epoch': 2,
#    'loss': 0.589531,
#    'rate': 0.589531,
#    'mse': 1.11475,
#    'val_loss': 0.489801,
#    'val_rate': 0.489801,
#    'val_mse': 1.10998},
#   {'epoch': 3,
#    'loss': 0.479843,
#    'rate': 0.479843,
#    'mse': 1.1121,
#    'val_loss': 0.4885,
#    'val_rate': 0.4885,
#    'val_mse': 1.11831},
#   {'epoch': 3,
#    'loss': 0.479843,
#    'rate': 0.479843,
#    'mse': 1.1121,
#    'val_loss': 0.4885,
#    'val_rate': 0.4885,
#    'val_mse': 1.11831},
#   {'epoch': 4,
#    'loss': 0.397131,
#    'rate': 0.397131,
#    'mse': 1.10967,
#    'val_loss': 0.355159,
#    'val_rate': 0.355159,
#    'val_mse': 1.10793},
#   {'epoch': 4,
#    'loss': 0.397131,
#    'rate': 0.397131,
#    'mse': 1.10967,
#    'val_loss': 0.355159,
#    'val_rate': 0.355159,
#    'val_mse': 1.10793}],
#  1e-17: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837411,
#    'val_rate': 0.837411,
#    'val_mse': 1.11889},
#   {'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837411,
#    'val_rate': 0.837411,
#    'val_mse': 1.11889},
#   {'epoch': 1,
#    'loss': 0.772476,
#    'rate': 0.772476,
#    'mse': 1.11801,
#    'val_loss': 0.644005,
#    'val_rate': 0.644005,
#    'val_mse': 1.11308},
#   {'epoch': 1,
#    'loss': 0.772476,
#    'rate': 0.772476,
#    'mse': 1.11801,
#    'val_loss': 0.644005,
#    'val_rate': 0.644005,
#    'val_mse': 1.11308},
#   {'epoch': 2,
#    'loss': 0.589445,
#    'rate': 0.589445,
#    'mse': 1.11475,
#    'val_loss': 0.485817,
#    'val_rate': 0.485817,
#    'val_mse': 1.11066},
#   {'epoch': 2,
#    'loss': 0.589445,
#    'rate': 0.589445,
#    'mse': 1.11475,
#    'val_loss': 0.485817,
#    'val_rate': 0.485817,
#    'val_mse': 1.11066},
#   {'epoch': 3,
#    'loss': 0.479936,
#    'rate': 0.479936,
#    'mse': 1.1121,
#    'val_loss': 0.491659,
#    'val_rate': 0.491659,
#    'val_mse': 1.11848},
#   {'epoch': 3,
#    'loss': 0.479936,
#    'rate': 0.479936,
#    'mse': 1.1121,
#    'val_loss': 0.491659,
#    'val_rate': 0.491659,
#    'val_mse': 1.11848},
#   {'epoch': 4,
#    'loss': 0.397126,
#    'rate': 0.397126,
#    'mse': 1.10967,
#    'val_loss': 0.355007,
#    'val_rate': 0.355007,
#    'val_mse': 1.10799},
#   {'epoch': 4,
#    'loss': 0.397126,
#    'rate': 0.397126,
#    'mse': 1.10967,
#    'val_loss': 0.355007,
#    'val_rate': 0.355007,
#    'val_mse': 1.10799}],
#  3e-17: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 1,
#    'loss': 0.772445,
#    'rate': 0.772445,
#    'mse': 1.11801,
#    'val_loss': 0.644965,
#    'val_rate': 0.644965,
#    'val_mse': 1.11298},
#   {'epoch': 1,
#    'loss': 0.772445,
#    'rate': 0.772445,
#    'mse': 1.11801,
#    'val_loss': 0.644965,
#    'val_rate': 0.644965,
#    'val_mse': 1.11298},
#   {'epoch': 2,
#    'loss': 0.589613,
#    'rate': 0.589613,
#    'mse': 1.11475,
#    'val_loss': 0.490346,
#    'val_rate': 0.490346,
#    'val_mse': 1.1099},
#   {'epoch': 2,
#    'loss': 0.589613,
#    'rate': 0.589613,
#    'mse': 1.11475,
#    'val_loss': 0.490346,
#    'val_rate': 0.490346,
#    'val_mse': 1.1099},
#   {'epoch': 3,
#    'loss': 0.479806,
#    'rate': 0.479806,
#    'mse': 1.1121,
#    'val_loss': 0.48871,
#    'val_rate': 0.48871,
#    'val_mse': 1.11832},
#   {'epoch': 3,
#    'loss': 0.479806,
#    'rate': 0.479806,
#    'mse': 1.1121,
#    'val_loss': 0.48871,
#    'val_rate': 0.48871,
#    'val_mse': 1.11832},
#   {'epoch': 4,
#    'loss': 0.397112,
#    'rate': 0.397112,
#    'mse': 1.10968,
#    'val_loss': 0.355642,
#    'val_rate': 0.355642,
#    'val_mse': 1.10772},
#   {'epoch': 4,
#    'loss': 0.397112,
#    'rate': 0.397112,
#    'mse': 1.10968,
#    'val_loss': 0.355642,
#    'val_rate': 0.355642,
#    'val_mse': 1.10772}],
#  1e-16: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837466,
#    'val_rate': 0.837466,
#    'val_mse': 1.11887},
#   {'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837466,
#    'val_rate': 0.837466,
#    'val_mse': 1.11887},
#   {'epoch': 1,
#    'loss': 0.772484,
#    'rate': 0.772484,
#    'mse': 1.11801,
#    'val_loss': 0.644301,
#    'val_rate': 0.644301,
#    'val_mse': 1.11305},
#   {'epoch': 1,
#    'loss': 0.772484,
#    'rate': 0.772484,
#    'mse': 1.11801,
#    'val_loss': 0.644301,
#    'val_rate': 0.644301,
#    'val_mse': 1.11305},
#   {'epoch': 2,
#    'loss': 0.589555,
#    'rate': 0.589555,
#    'mse': 1.11475,
#    'val_loss': 0.490111,
#    'val_rate': 0.490111,
#    'val_mse': 1.10993},
#   {'epoch': 2,
#    'loss': 0.589555,
#    'rate': 0.589555,
#    'mse': 1.11475,
#    'val_loss': 0.490111,
#    'val_rate': 0.490111,
#    'val_mse': 1.10993},
#   {'epoch': 3,
#    'loss': 0.479852,
#    'rate': 0.479852,
#    'mse': 1.1121,
#    'val_loss': 0.486913,
#    'val_rate': 0.486913,
#    'val_mse': 1.11823},
#   {'epoch': 3,
#    'loss': 0.479852,
#    'rate': 0.479852,
#    'mse': 1.1121,
#    'val_loss': 0.486913,
#    'val_rate': 0.486913,
#    'val_mse': 1.11823},
#   {'epoch': 4,
#    'loss': 0.39715,
#    'rate': 0.39715,
#    'mse': 1.10967,
#    'val_loss': 0.355304,
#    'val_rate': 0.355304,
#    'val_mse': 1.10789},
#   {'epoch': 4,
#    'loss': 0.39715,
#    'rate': 0.39715,
#    'mse': 1.10967,
#    'val_loss': 0.355304,
#    'val_rate': 0.355304,
#    'val_mse': 1.10789}],
#  3e-16: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11882},
#   {'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11882},
#   {'epoch': 1,
#    'loss': 0.772481,
#    'rate': 0.772481,
#    'mse': 1.11801,
#    'val_loss': 0.644713,
#    'val_rate': 0.644713,
#    'val_mse': 1.11301},
#   {'epoch': 1,
#    'loss': 0.772481,
#    'rate': 0.772481,
#    'mse': 1.11801,
#    'val_loss': 0.644713,
#    'val_rate': 0.644713,
#    'val_mse': 1.11301},
#   {'epoch': 2,
#    'loss': 0.589532,
#    'rate': 0.589532,
#    'mse': 1.11475,
#    'val_loss': 0.489107,
#    'val_rate': 0.489107,
#    'val_mse': 1.11008},
#   {'epoch': 2,
#    'loss': 0.589532,
#    'rate': 0.589532,
#    'mse': 1.11475,
#    'val_loss': 0.489107,
#    'val_rate': 0.489107,
#    'val_mse': 1.11008},
#   {'epoch': 3,
#    'loss': 0.479823,
#    'rate': 0.479823,
#    'mse': 1.1121,
#    'val_loss': 0.489916,
#    'val_rate': 0.489916,
#    'val_mse': 1.11839},
#   {'epoch': 3,
#    'loss': 0.479823,
#    'rate': 0.479823,
#    'mse': 1.1121,
#    'val_loss': 0.489916,
#    'val_rate': 0.489916,
#    'val_mse': 1.11839},
#   {'epoch': 4,
#    'loss': 0.397117,
#    'rate': 0.397117,
#    'mse': 1.10968,
#    'val_loss': 0.355656,
#    'val_rate': 0.355656,
#    'val_mse': 1.10776},
#   {'epoch': 4,
#    'loss': 0.397117,
#    'rate': 0.397117,
#    'mse': 1.10968,
#    'val_loss': 0.355656,
#    'val_rate': 0.355656,
#    'val_mse': 1.10776}],
#  1e-15: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837414,
#    'val_rate': 0.837414,
#    'val_mse': 1.11885},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837414,
#    'val_rate': 0.837414,
#    'val_mse': 1.11885},
#   {'epoch': 1,
#    'loss': 0.772487,
#    'rate': 0.772487,
#    'mse': 1.11801,
#    'val_loss': 0.644598,
#    'val_rate': 0.644598,
#    'val_mse': 1.11302},
#   {'epoch': 1,
#    'loss': 0.772487,
#    'rate': 0.772487,
#    'mse': 1.11801,
#    'val_loss': 0.644598,
#    'val_rate': 0.644598,
#    'val_mse': 1.11302},
#   {'epoch': 2,
#    'loss': 0.589543,
#    'rate': 0.589543,
#    'mse': 1.11475,
#    'val_loss': 0.488747,
#    'val_rate': 0.488747,
#    'val_mse': 1.11014},
#   {'epoch': 2,
#    'loss': 0.589543,
#    'rate': 0.589543,
#    'mse': 1.11475,
#    'val_loss': 0.488747,
#    'val_rate': 0.488747,
#    'val_mse': 1.11014},
#   {'epoch': 3,
#    'loss': 0.479867,
#    'rate': 0.479867,
#    'mse': 1.1121,
#    'val_loss': 0.488585,
#    'val_rate': 0.488585,
#    'val_mse': 1.11831},
#   {'epoch': 3,
#    'loss': 0.479867,
#    'rate': 0.479867,
#    'mse': 1.1121,
#    'val_loss': 0.488585,
#    'val_rate': 0.488585,
#    'val_mse': 1.11831},
#   {'epoch': 4,
#    'loss': 0.397077,
#    'rate': 0.397077,
#    'mse': 1.10967,
#    'val_loss': 0.356238,
#    'val_rate': 0.356238,
#    'val_mse': 1.10759},
#   {'epoch': 4,
#    'loss': 0.397077,
#    'rate': 0.397077,
#    'mse': 1.10967,
#    'val_loss': 0.356238,
#    'val_rate': 0.356238,
#    'val_mse': 1.10759}],
#  3e-15: [{'epoch': 0,
#    'loss': 3.63896,
#    'rate': 3.63896,
#    'mse': 1.12019,
#    'val_loss': 0.837452,
#    'val_rate': 0.837452,
#    'val_mse': 1.11891},
#   {'epoch': 0,
#    'loss': 3.63896,
#    'rate': 3.63896,
#    'mse': 1.12019,
#    'val_loss': 0.837452,
#    'val_rate': 0.837452,
#    'val_mse': 1.11891},
#   {'epoch': 1,
#    'loss': 0.772449,
#    'rate': 0.772449,
#    'mse': 1.11801,
#    'val_loss': 0.645036,
#    'val_rate': 0.645036,
#    'val_mse': 1.11297},
#   {'epoch': 1,
#    'loss': 0.772449,
#    'rate': 0.772449,
#    'mse': 1.11801,
#    'val_loss': 0.645036,
#    'val_rate': 0.645036,
#    'val_mse': 1.11297},
#   {'epoch': 2,
#    'loss': 0.589515,
#    'rate': 0.589515,
#    'mse': 1.11475,
#    'val_loss': 0.487694,
#    'val_rate': 0.487694,
#    'val_mse': 1.11031},
#   {'epoch': 2,
#    'loss': 0.589515,
#    'rate': 0.589515,
#    'mse': 1.11475,
#    'val_loss': 0.487694,
#    'val_rate': 0.487694,
#    'val_mse': 1.11031},
#   {'epoch': 3,
#    'loss': 0.479885,
#    'rate': 0.479885,
#    'mse': 1.1121,
#    'val_loss': 0.487608,
#    'val_rate': 0.487608,
#    'val_mse': 1.11826},
#   {'epoch': 3,
#    'loss': 0.479885,
#    'rate': 0.479885,
#    'mse': 1.1121,
#    'val_loss': 0.487608,
#    'val_rate': 0.487608,
#    'val_mse': 1.11826},
#   {'epoch': 4,
#    'loss': 0.397085,
#    'rate': 0.397085,
#    'mse': 1.10967,
#    'val_loss': 0.355602,
#    'val_rate': 0.355602,
#    'val_mse': 1.10778},
#   {'epoch': 4,
#    'loss': 0.397085,
#    'rate': 0.397085,
#    'mse': 1.10967,
#    'val_loss': 0.355602,
#    'val_rate': 0.355602,
#    'val_mse': 1.10778}],
#  1e-14: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837377,
#    'val_rate': 0.837377,
#    'val_mse': 1.11879},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837377,
#    'val_rate': 0.837377,
#    'val_mse': 1.11879},
#   {'epoch': 1,
#    'loss': 0.772493,
#    'rate': 0.772493,
#    'mse': 1.11801,
#    'val_loss': 0.644277,
#    'val_rate': 0.644277,
#    'val_mse': 1.11305},
#   {'epoch': 1,
#    'loss': 0.772493,
#    'rate': 0.772493,
#    'mse': 1.11801,
#    'val_loss': 0.644277,
#    'val_rate': 0.644277,
#    'val_mse': 1.11305},
#   {'epoch': 2,
#    'loss': 0.589464,
#    'rate': 0.589464,
#    'mse': 1.11475,
#    'val_loss': 0.487057,
#    'val_rate': 0.487057,
#    'val_mse': 1.11042},
#   {'epoch': 2,
#    'loss': 0.589464,
#    'rate': 0.589464,
#    'mse': 1.11475,
#    'val_loss': 0.487057,
#    'val_rate': 0.487057,
#    'val_mse': 1.11042},
#   {'epoch': 3,
#    'loss': 0.479957,
#    'rate': 0.479957,
#    'mse': 1.1121,
#    'val_loss': 0.486784,
#    'val_rate': 0.486784,
#    'val_mse': 1.11822},
#   {'epoch': 3,
#    'loss': 0.479957,
#    'rate': 0.479957,
#    'mse': 1.1121,
#    'val_loss': 0.486784,
#    'val_rate': 0.486784,
#    'val_mse': 1.11822},
#   {'epoch': 4,
#    'loss': 0.397086,
#    'rate': 0.397086,
#    'mse': 1.10967,
#    'val_loss': 0.355708,
#    'val_rate': 0.355708,
#    'val_mse': 1.10774},
#   {'epoch': 4,
#    'loss': 0.397086,
#    'rate': 0.397086,
#    'mse': 1.10967,
#    'val_loss': 0.355708,
#    'val_rate': 0.355708,
#    'val_mse': 1.10774}],
#  3e-14: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837341,
#    'val_rate': 0.837341,
#    'val_mse': 1.11882},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837341,
#    'val_rate': 0.837341,
#    'val_mse': 1.11882},
#   {'epoch': 1,
#    'loss': 0.772476,
#    'rate': 0.772476,
#    'mse': 1.11801,
#    'val_loss': 0.645514,
#    'val_rate': 0.645514,
#    'val_mse': 1.11293},
#   {'epoch': 1,
#    'loss': 0.772476,
#    'rate': 0.772476,
#    'mse': 1.11801,
#    'val_loss': 0.645514,
#    'val_rate': 0.645514,
#    'val_mse': 1.11293},
#   {'epoch': 2,
#    'loss': 0.589592,
#    'rate': 0.589592,
#    'mse': 1.11475,
#    'val_loss': 0.490016,
#    'val_rate': 0.490016,
#    'val_mse': 1.10994},
#   {'epoch': 2,
#    'loss': 0.589592,
#    'rate': 0.589592,
#    'mse': 1.11475,
#    'val_loss': 0.490016,
#    'val_rate': 0.490016,
#    'val_mse': 1.10994},
#   {'epoch': 3,
#    'loss': 0.479837,
#    'rate': 0.479837,
#    'mse': 1.1121,
#    'val_loss': 0.486043,
#    'val_rate': 0.486043,
#    'val_mse': 1.11818},
#   {'epoch': 3,
#    'loss': 0.479837,
#    'rate': 0.479837,
#    'mse': 1.1121,
#    'val_loss': 0.486043,
#    'val_rate': 0.486043,
#    'val_mse': 1.11818},
#   {'epoch': 4,
#    'loss': 0.397145,
#    'rate': 0.397145,
#    'mse': 1.10967,
#    'val_loss': 0.355099,
#    'val_rate': 0.355099,
#    'val_mse': 1.10795},
#   {'epoch': 4,
#    'loss': 0.397145,
#    'rate': 0.397145,
#    'mse': 1.10967,
#    'val_loss': 0.355099,
#    'val_rate': 0.355099,
#    'val_mse': 1.10795}],
#  1e-13: [{'epoch': 0,
#    'loss': 3.63893,
#    'rate': 3.63893,
#    'mse': 1.12019,
#    'val_loss': 0.837484,
#    'val_rate': 0.837484,
#    'val_mse': 1.1189},
#   {'epoch': 0,
#    'loss': 3.63893,
#    'rate': 3.63893,
#    'mse': 1.12019,
#    'val_loss': 0.837484,
#    'val_rate': 0.837484,
#    'val_mse': 1.1189},
#   {'epoch': 1,
#    'loss': 0.772466,
#    'rate': 0.772466,
#    'mse': 1.11801,
#    'val_loss': 0.644836,
#    'val_rate': 0.644836,
#    'val_mse': 1.11299},
#   {'epoch': 1,
#    'loss': 0.772466,
#    'rate': 0.772466,
#    'mse': 1.11801,
#    'val_loss': 0.644836,
#    'val_rate': 0.644836,
#    'val_mse': 1.11299},
#   {'epoch': 2,
#    'loss': 0.589483,
#    'rate': 0.589483,
#    'mse': 1.11475,
#    'val_loss': 0.486159,
#    'val_rate': 0.486159,
#    'val_mse': 1.11059},
#   {'epoch': 2,
#    'loss': 0.589483,
#    'rate': 0.589483,
#    'mse': 1.11475,
#    'val_loss': 0.486159,
#    'val_rate': 0.486159,
#    'val_mse': 1.11059},
#   {'epoch': 3,
#    'loss': 0.479889,
#    'rate': 0.479889,
#    'mse': 1.1121,
#    'val_loss': 0.486679,
#    'val_rate': 0.486679,
#    'val_mse': 1.11821},
#   {'epoch': 3,
#    'loss': 0.479889,
#    'rate': 0.479889,
#    'mse': 1.1121,
#    'val_loss': 0.486679,
#    'val_rate': 0.486679,
#    'val_mse': 1.11821},
#   {'epoch': 4,
#    'loss': 0.397092,
#    'rate': 0.397092,
#    'mse': 1.10967,
#    'val_loss': 0.356107,
#    'val_rate': 0.356107,
#    'val_mse': 1.10763},
#   {'epoch': 4,
#    'loss': 0.397092,
#    'rate': 0.397092,
#    'mse': 1.10967,
#    'val_loss': 0.356107,
#    'val_rate': 0.356107,
#    'val_mse': 1.10763}],
#  3e-13: [{'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 1.12019,
#    'val_loss': 0.837412,
#    'val_rate': 0.837412,
#    'val_mse': 1.11884},
#   {'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 1.12019,
#    'val_loss': 0.837412,
#    'val_rate': 0.837412,
#    'val_mse': 1.11884},
#   {'epoch': 1,
#    'loss': 0.772437,
#    'rate': 0.772437,
#    'mse': 1.11801,
#    'val_loss': 0.644766,
#    'val_rate': 0.644766,
#    'val_mse': 1.113},
#   {'epoch': 1,
#    'loss': 0.772437,
#    'rate': 0.772437,
#    'mse': 1.11801,
#    'val_loss': 0.644766,
#    'val_rate': 0.644766,
#    'val_mse': 1.113},
#   {'epoch': 2,
#    'loss': 0.589553,
#    'rate': 0.589553,
#    'mse': 1.11475,
#    'val_loss': 0.488157,
#    'val_rate': 0.488157,
#    'val_mse': 1.11024},
#   {'epoch': 2,
#    'loss': 0.589553,
#    'rate': 0.589553,
#    'mse': 1.11475,
#    'val_loss': 0.488157,
#    'val_rate': 0.488157,
#    'val_mse': 1.11024},
#   {'epoch': 3,
#    'loss': 0.479844,
#    'rate': 0.479844,
#    'mse': 1.1121,
#    'val_loss': 0.492937,
#    'val_rate': 0.492937,
#    'val_mse': 1.11855},
#   {'epoch': 3,
#    'loss': 0.479844,
#    'rate': 0.479844,
#    'mse': 1.1121,
#    'val_loss': 0.492937,
#    'val_rate': 0.492937,
#    'val_mse': 1.11855},
#   {'epoch': 4,
#    'loss': 0.397145,
#    'rate': 0.397145,
#    'mse': 1.10967,
#    'val_loss': 0.354756,
#    'val_rate': 0.354756,
#    'val_mse': 1.10809},
#   {'epoch': 4,
#    'loss': 0.397145,
#    'rate': 0.397145,
#    'mse': 1.10967,
#    'val_loss': 0.354756,
#    'val_rate': 0.354756,
#    'val_mse': 1.10809}],
#  1e-12: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 1,
#    'loss': 0.772461,
#    'rate': 0.772461,
#    'mse': 1.11801,
#    'val_loss': 0.644356,
#    'val_rate': 0.644356,
#    'val_mse': 1.11305},
#   {'epoch': 1,
#    'loss': 0.772461,
#    'rate': 0.772461,
#    'mse': 1.11801,
#    'val_loss': 0.644356,
#    'val_rate': 0.644356,
#    'val_mse': 1.11305},
#   {'epoch': 2,
#    'loss': 0.589569,
#    'rate': 0.589569,
#    'mse': 1.11475,
#    'val_loss': 0.488991,
#    'val_rate': 0.488991,
#    'val_mse': 1.1101},
#   {'epoch': 2,
#    'loss': 0.589569,
#    'rate': 0.589569,
#    'mse': 1.11475,
#    'val_loss': 0.488991,
#    'val_rate': 0.488991,
#    'val_mse': 1.1101},
#   {'epoch': 3,
#    'loss': 0.479818,
#    'rate': 0.479818,
#    'mse': 1.1121,
#    'val_loss': 0.487102,
#    'val_rate': 0.487102,
#    'val_mse': 1.11823},
#   {'epoch': 3,
#    'loss': 0.479818,
#    'rate': 0.479818,
#    'mse': 1.1121,
#    'val_loss': 0.487102,
#    'val_rate': 0.487102,
#    'val_mse': 1.11823},
#   {'epoch': 4,
#    'loss': 0.397107,
#    'rate': 0.397107,
#    'mse': 1.10967,
#    'val_loss': 0.355268,
#    'val_rate': 0.355268,
#    'val_mse': 1.10788},
#   {'epoch': 4,
#    'loss': 0.397107,
#    'rate': 0.397107,
#    'mse': 1.10967,
#    'val_loss': 0.355268,
#    'val_rate': 0.355268,
#    'val_mse': 1.10788}],
#  3e-12: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12019,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11885},
#   {'epoch': 1,
#    'loss': 0.77247,
#    'rate': 0.77247,
#    'mse': 1.118,
#    'val_loss': 0.644285,
#    'val_rate': 0.644285,
#    'val_mse': 1.11304},
#   {'epoch': 1,
#    'loss': 0.77247,
#    'rate': 0.77247,
#    'mse': 1.118,
#    'val_loss': 0.644285,
#    'val_rate': 0.644285,
#    'val_mse': 1.11304},
#   {'epoch': 2,
#    'loss': 0.589531,
#    'rate': 0.589531,
#    'mse': 1.11473,
#    'val_loss': 0.489801,
#    'val_rate': 0.489801,
#    'val_mse': 1.10995},
#   {'epoch': 2,
#    'loss': 0.589531,
#    'rate': 0.589531,
#    'mse': 1.11473,
#    'val_loss': 0.489801,
#    'val_rate': 0.489801,
#    'val_mse': 1.10995},
#   {'epoch': 3,
#    'loss': 0.479843,
#    'rate': 0.479843,
#    'mse': 1.11207,
#    'val_loss': 0.4885,
#    'val_rate': 0.4885,
#    'val_mse': 1.11828},
#   {'epoch': 3,
#    'loss': 0.479843,
#    'rate': 0.479843,
#    'mse': 1.11207,
#    'val_loss': 0.4885,
#    'val_rate': 0.4885,
#    'val_mse': 1.11828},
#   {'epoch': 4,
#    'loss': 0.397131,
#    'rate': 0.397131,
#    'mse': 1.10964,
#    'val_loss': 0.355159,
#    'val_rate': 0.355159,
#    'val_mse': 1.10789},
#   {'epoch': 4,
#    'loss': 0.397131,
#    'rate': 0.397131,
#    'mse': 1.10964,
#    'val_loss': 0.355159,
#    'val_rate': 0.355159,
#    'val_mse': 1.10789}],
#  1e-11: [{'epoch': 0,
#    'loss': 3.63893,
#    'rate': 3.63893,
#    'mse': 1.12017,
#    'val_loss': 0.837389,
#    'val_rate': 0.837389,
#    'val_mse': 1.11879},
#   {'epoch': 0,
#    'loss': 3.63893,
#    'rate': 3.63893,
#    'mse': 1.12017,
#    'val_loss': 0.837389,
#    'val_rate': 0.837389,
#    'val_mse': 1.11879},
#   {'epoch': 1,
#    'loss': 0.772463,
#    'rate': 0.772463,
#    'mse': 1.1179,
#    'val_loss': 0.645159,
#    'val_rate': 0.645159,
#    'val_mse': 1.1128},
#   {'epoch': 1,
#    'loss': 0.772463,
#    'rate': 0.772463,
#    'mse': 1.1179,
#    'val_loss': 0.645159,
#    'val_rate': 0.645159,
#    'val_mse': 1.1128},
#   {'epoch': 2,
#    'loss': 0.58946,
#    'rate': 0.58946,
#    'mse': 1.11454,
#    'val_loss': 0.485793,
#    'val_rate': 0.485793,
#    'val_mse': 1.1104},
#   {'epoch': 2,
#    'loss': 0.58946,
#    'rate': 0.58946,
#    'mse': 1.11454,
#    'val_loss': 0.485793,
#    'val_rate': 0.485793,
#    'val_mse': 1.1104},
#   {'epoch': 3,
#    'loss': 0.479928,
#    'rate': 0.479928,
#    'mse': 1.11179,
#    'val_loss': 0.488986,
#    'val_rate': 0.488986,
#    'val_mse': 1.11797},
#   {'epoch': 3,
#    'loss': 0.479928,
#    'rate': 0.479928,
#    'mse': 1.11179,
#    'val_loss': 0.488986,
#    'val_rate': 0.488986,
#    'val_mse': 1.11797},
#   {'epoch': 4,
#    'loss': 0.397159,
#    'rate': 0.397159,
#    'mse': 1.10925,
#    'val_loss': 0.35542,
#    'val_rate': 0.35542,
#    'val_mse': 1.10736},
#   {'epoch': 4,
#    'loss': 0.397159,
#    'rate': 0.397159,
#    'mse': 1.10925,
#    'val_loss': 0.35542,
#    'val_rate': 0.35542,
#    'val_mse': 1.10736}],
#  3e-11: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12,
#    'val_loss': 0.837421,
#    'val_rate': 0.837421,
#    'val_mse': 1.11837},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.12,
#    'val_loss': 0.837421,
#    'val_rate': 0.837421,
#    'val_mse': 1.11837},
#   {'epoch': 1,
#    'loss': 0.772465,
#    'rate': 0.772465,
#    'mse': 1.11706,
#    'val_loss': 0.644776,
#    'val_rate': 0.644776,
#    'val_mse': 1.11161},
#   {'epoch': 1,
#    'loss': 0.772465,
#    'rate': 0.772465,
#    'mse': 1.11706,
#    'val_loss': 0.644776,
#    'val_rate': 0.644776,
#    'val_mse': 1.11161},
#   {'epoch': 2,
#    'loss': 0.589634,
#    'rate': 0.589634,
#    'mse': 1.1129,
#    'val_loss': 0.490491,
#    'val_rate': 0.490491,
#    'val_mse': 1.10756},
#   {'epoch': 2,
#    'loss': 0.589634,
#    'rate': 0.589634,
#    'mse': 1.1129,
#    'val_loss': 0.490491,
#    'val_rate': 0.490491,
#    'val_mse': 1.10756},
#   {'epoch': 3,
#    'loss': 0.479819,
#    'rate': 0.479819,
#    'mse': 1.10931,
#    'val_loss': 0.486617,
#    'val_rate': 0.486617,
#    'val_mse': 1.11492},
#   {'epoch': 3,
#    'loss': 0.479819,
#    'rate': 0.479819,
#    'mse': 1.10931,
#    'val_loss': 0.486617,
#    'val_rate': 0.486617,
#    'val_mse': 1.11492},
#   {'epoch': 4,
#    'loss': 0.397072,
#    'rate': 0.397072,
#    'mse': 1.10596,
#    'val_loss': 0.355538,
#    'val_rate': 0.355538,
#    'val_mse': 1.10362},
#   {'epoch': 4,
#    'loss': 0.397072,
#    'rate': 0.397072,
#    'mse': 1.10596,
#    'val_loss': 0.355538,
#    'val_rate': 0.355538,
#    'val_mse': 1.10362}],
#  1e-10: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.11854,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11468},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.11854,
#    'val_loss': 0.837382,
#    'val_rate': 0.837382,
#    'val_mse': 1.11468},
#   {'epoch': 1,
#    'loss': 0.772491,
#    'rate': 0.772491,
#    'mse': 1.11071,
#    'val_loss': 0.644706,
#    'val_rate': 0.644706,
#    'val_mse': 1.10253},
#   {'epoch': 1,
#    'loss': 0.772491,
#    'rate': 0.772491,
#    'mse': 1.11071,
#    'val_loss': 0.644706,
#    'val_rate': 0.644706,
#    'val_mse': 1.10253},
#   {'epoch': 2,
#    'loss': 0.589405,
#    'rate': 0.589405,
#    'mse': 1.10095,
#    'val_loss': 0.485333,
#    'val_rate': 0.485333,
#    'val_mse': 1.09375},
#   {'epoch': 2,
#    'loss': 0.589405,
#    'rate': 0.589405,
#    'mse': 1.10095,
#    'val_loss': 0.485333,
#    'val_rate': 0.485333,
#    'val_mse': 1.09375},
#   {'epoch': 3,
#    'loss': 0.479945,
#    'rate': 0.479945,
#    'mse': 1.09183,
#    'val_loss': 0.486479,
#    'val_rate': 0.486479,
#    'val_mse': 1.09451},
#   {'epoch': 3,
#    'loss': 0.479945,
#    'rate': 0.479945,
#    'mse': 1.09183,
#    'val_loss': 0.486479,
#    'val_rate': 0.486479,
#    'val_mse': 1.09451},
#   {'epoch': 4,
#    'loss': 0.397085,
#    'rate': 0.397085,
#    'mse': 1.083,
#    'val_loss': 0.355713,
#    'val_rate': 0.355713,
#    'val_mse': 1.07796},
#   {'epoch': 4,
#    'loss': 0.397085,
#    'rate': 0.397085,
#    'mse': 1.083,
#    'val_loss': 0.355713,
#    'val_rate': 0.355713,
#    'val_mse': 1.07796}],
#  3e-10: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.11331,
#    'val_loss': 0.837439,
#    'val_rate': 0.837439,
#    'val_mse': 1.10244},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 1.11331,
#    'val_loss': 0.837439,
#    'val_rate': 0.837439,
#    'val_mse': 1.10244},
#   {'epoch': 1,
#    'loss': 0.772457,
#    'rate': 0.772457,
#    'mse': 1.09051,
#    'val_loss': 0.644026,
#    'val_rate': 0.644026,
#    'val_mse': 1.07449},
#   {'epoch': 1,
#    'loss': 0.772457,
#    'rate': 0.772457,
#    'mse': 1.09051,
#    'val_loss': 0.644026,
#    'val_rate': 0.644026,
#    'val_mse': 1.07449},
#   {'epoch': 2,
#    'loss': 0.589522,
#    'rate': 0.589522,
#    'mse': 1.06497,
#    'val_loss': 0.48926,
#    'val_rate': 0.48926,
#    'val_mse': 1.04956},
#   {'epoch': 2,
#    'loss': 0.589522,
#    'rate': 0.589522,
#    'mse': 1.06497,
#    'val_loss': 0.48926,
#    'val_rate': 0.48926,
#    'val_mse': 1.04956},
#   {'epoch': 3,
#    'loss': 0.479868,
#    'rate': 0.479868,
#    'mse': 1.04076,
#    'val_loss': 0.489795,
#    'val_rate': 0.489795,
#    'val_mse': 1.03595},
#   {'epoch': 3,
#    'loss': 0.479868,
#    'rate': 0.479868,
#    'mse': 1.04076,
#    'val_loss': 0.489795,
#    'val_rate': 0.489795,
#    'val_mse': 1.03595},
#   {'epoch': 4,
#    'loss': 0.397135,
#    'rate': 0.397135,
#    'mse': 1.01783,
#    'val_loss': 0.355377,
#    'val_rate': 0.355377,
#    'val_mse': 1.00615},
#   {'epoch': 4,
#    'loss': 0.397135,
#    'rate': 0.397135,
#    'mse': 1.01783,
#    'val_loss': 0.355377,
#    'val_rate': 0.355377,
#    'val_mse': 1.00615}],
#  1e-09: [{'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 1.0963,
#    'val_loss': 0.837356,
#    'val_rate': 0.837356,
#    'val_mse': 1.06355},
#   {'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 1.0963,
#    'val_loss': 0.837356,
#    'val_rate': 0.837356,
#    'val_mse': 1.06355},
#   {'epoch': 1,
#    'loss': 0.77244,
#    'rate': 0.77244,
#    'mse': 1.02869,
#    'val_loss': 0.644558,
#    'val_rate': 0.644558,
#    'val_mse': 0.990829},
#   {'epoch': 1,
#    'loss': 0.77244,
#    'rate': 0.77244,
#    'mse': 1.02869,
#    'val_loss': 0.644558,
#    'val_rate': 0.644558,
#    'val_mse': 0.990829},
#   {'epoch': 2,
#    'loss': 0.589574,
#    'rate': 0.589574,
#    'mse': 0.961249,
#    'val_loss': 0.489357,
#    'val_rate': 0.489357,
#    'val_mse': 0.927619},
#   {'epoch': 2,
#    'loss': 0.589574,
#    'rate': 0.589574,
#    'mse': 0.961249,
#    'val_loss': 0.489357,
#    'val_rate': 0.489357,
#    'val_mse': 0.927619},
#   {'epoch': 3,
#    'loss': 0.479865,
#    'rate': 0.479865,
#    'mse': 0.901922,
#    'val_loss': 0.488937,
#    'val_rate': 0.488937,
#    'val_mse': 0.880357},
#   {'epoch': 3,
#    'loss': 0.479865,
#    'rate': 0.479865,
#    'mse': 0.901922,
#    'val_loss': 0.488937,
#    'val_rate': 0.488937,
#    'val_mse': 0.880357},
#   {'epoch': 4,
#    'loss': 0.3971,
#    'rate': 0.3971,
#    'mse': 0.849802,
#    'val_loss': 0.355287,
#    'val_rate': 0.355287,
#    'val_mse': 0.825394},
#   {'epoch': 4,
#    'loss': 0.3971,
#    'rate': 0.3971,
#    'mse': 0.849802,
#    'val_loss': 0.355287,
#    'val_rate': 0.355287,
#    'val_mse': 0.825394}],
#  3e-09: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.05256,
#    'val_loss': 0.837308,
#    'val_rate': 0.837308,
#    'val_mse': 0.967875},
#   {'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 1.05256,
#    'val_loss': 0.837308,
#    'val_rate': 0.837308,
#    'val_mse': 0.967875},
#   {'epoch': 1,
#    'loss': 0.772485,
#    'rate': 0.772485,
#    'mse': 0.889196,
#    'val_loss': 0.644057,
#    'val_rate': 0.644057,
#    'val_mse': 0.814441},
#   {'epoch': 1,
#    'loss': 0.772485,
#    'rate': 0.772485,
#    'mse': 0.889196,
#    'val_loss': 0.644057,
#    'val_rate': 0.644057,
#    'val_mse': 0.814441},
#   {'epoch': 2,
#    'loss': 0.589412,
#    'rate': 0.589412,
#    'mse': 0.757545,
#    'val_loss': 0.485513,
#    'val_rate': 0.485513,
#    'val_mse': 0.702744},
#   {'epoch': 2,
#    'loss': 0.589412,
#    'rate': 0.589412,
#    'mse': 0.757545,
#    'val_loss': 0.485513,
#    'val_rate': 0.485513,
#    'val_mse': 0.702744},
#   {'epoch': 3,
#    'loss': 0.479931,
#    'rate': 0.479931,
#    'mse': 0.660192,
#    'val_loss': 0.487806,
#    'val_rate': 0.487806,
#    'val_mse': 0.623668},
#   {'epoch': 3,
#    'loss': 0.479931,
#    'rate': 0.479931,
#    'mse': 0.660192,
#    'val_loss': 0.487806,
#    'val_rate': 0.487806,
#    'val_mse': 0.623668},
#   {'epoch': 4,
#    'loss': 0.397093,
#    'rate': 0.397093,
#    'mse': 0.5861,
#    'val_loss': 0.355215,
#    'val_rate': 0.355215,
#    'val_mse': 0.554579},
#   {'epoch': 4,
#    'loss': 0.397093,
#    'rate': 0.397093,
#    'mse': 0.5861,
#    'val_loss': 0.355215,
#    'val_rate': 0.355215,
#    'val_mse': 0.554579}],
#  1e-08: [{'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 0.933638,
#    'val_loss': 0.8374,
#    'val_rate': 0.8374,
#    'val_mse': 0.740024},
#   {'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 0.933638,
#    'val_loss': 0.8374,
#    'val_rate': 0.8374,
#    'val_mse': 0.740024},
#   {'epoch': 1,
#    'loss': 0.772482,
#    'rate': 0.772482,
#    'mse': 0.613063,
#    'val_loss': 0.644251,
#    'val_rate': 0.644251,
#    'val_mse': 0.510902},
#   {'epoch': 1,
#    'loss': 0.772482,
#    'rate': 0.772482,
#    'mse': 0.613063,
#    'val_loss': 0.644251,
#    'val_rate': 0.644251,
#    'val_mse': 0.510902},
#   {'epoch': 2,
#    'loss': 0.589586,
#    'rate': 0.589586,
#    'mse': 0.44681,
#    'val_loss': 0.490026,
#    'val_rate': 0.490026,
#    'val_mse': 0.391702},
#   {'epoch': 2,
#    'loss': 0.589586,
#    'rate': 0.589586,
#    'mse': 0.44681,
#    'val_loss': 0.490026,
#    'val_rate': 0.490026,
#    'val_mse': 0.391702},
#   {'epoch': 3,
#    'loss': 0.479775,
#    'rate': 0.479775,
#    'mse': 0.353742,
#    'val_loss': 0.490258,
#    'val_rate': 0.490258,
#    'val_mse': 0.322001},
#   {'epoch': 3,
#    'loss': 0.479775,
#    'rate': 0.479775,
#    'mse': 0.353742,
#    'val_loss': 0.490258,
#    'val_rate': 0.490258,
#    'val_mse': 0.322001},
#   {'epoch': 4,
#    'loss': 0.397129,
#    'rate': 0.397129,
#    'mse': 0.294409,
#    'val_loss': 0.355083,
#    'val_rate': 0.355083,
#    'val_mse': 0.271449},
#   {'epoch': 4,
#    'loss': 0.397129,
#    'rate': 0.397129,
#    'mse': 0.294409,
#    'val_loss': 0.355083,
#    'val_rate': 0.355083,
#    'val_mse': 0.271449}],
#  3e-08: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 0.737423,
#    'val_loss': 0.837474,
#    'val_rate': 0.837474,
#    'val_mse': 0.45238},
#   {'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 0.737423,
#    'val_loss': 0.837474,
#    'val_rate': 0.837474,
#    'val_mse': 0.45238},
#   {'epoch': 1,
#    'loss': 0.772485,
#    'rate': 0.772485,
#    'mse': 0.339106,
#    'val_loss': 0.643967,
#    'val_rate': 0.643967,
#    'val_mse': 0.259921},
#   {'epoch': 1,
#    'loss': 0.772485,
#    'rate': 0.772485,
#    'mse': 0.339106,
#    'val_loss': 0.643967,
#    'val_rate': 0.643967,
#    'val_mse': 0.259921},
#   {'epoch': 2,
#    'loss': 0.589499,
#    'rate': 0.589499,
#    'mse': 0.218206,
#    'val_loss': 0.488705,
#    'val_rate': 0.488705,
#    'val_mse': 0.184665},
#   {'epoch': 2,
#    'loss': 0.589499,
#    'rate': 0.589499,
#    'mse': 0.218206,
#    'val_loss': 0.488705,
#    'val_rate': 0.488705,
#    'val_mse': 0.184665},
#   {'epoch': 3,
#    'loss': 0.479846,
#    'rate': 0.479846,
#    'mse': 0.163213,
#    'val_loss': 0.490083,
#    'val_rate': 0.490083,
#    'val_mse': 0.14595},
#   {'epoch': 3,
#    'loss': 0.479846,
#    'rate': 0.479846,
#    'mse': 0.163213,
#    'val_loss': 0.490083,
#    'val_rate': 0.490083,
#    'val_mse': 0.14595},
#   {'epoch': 4,
#    'loss': 0.397096,
#    'rate': 0.397096,
#    'mse': 0.131786,
#    'val_loss': 0.355593,
#    'val_rate': 0.355593,
#    'val_mse': 0.120241},
#   {'epoch': 4,
#    'loss': 0.397096,
#    'rate': 0.397096,
#    'mse': 0.131786,
#    'val_loss': 0.355593,
#    'val_rate': 0.355593,
#    'val_mse': 0.120241}],
#  1e-07: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 0.48266,
#    'val_loss': 0.837404,
#    'val_rate': 0.837404,
#    'val_mse': 0.204518},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 0.48266,
#    'val_loss': 0.837404,
#    'val_rate': 0.837404,
#    'val_mse': 0.204518},
#   {'epoch': 1,
#    'loss': 0.772478,
#    'rate': 0.772478,
#    'mse': 0.144152,
#    'val_loss': 0.643887,
#    'val_rate': 0.643887,
#    'val_mse': 0.105794},
#   {'epoch': 1,
#    'loss': 0.772478,
#    'rate': 0.772478,
#    'mse': 0.144152,
#    'val_loss': 0.643887,
#    'val_rate': 0.643887,
#    'val_mse': 0.105794},
#   {'epoch': 2,
#    'loss': 0.58941,
#    'rate': 0.58941,
#    'mse': 0.0881875,
#    'val_loss': 0.48535,
#    'val_rate': 0.48535,
#    'val_mse': 0.0745503},
#   {'epoch': 2,
#    'loss': 0.58941,
#    'rate': 0.58941,
#    'mse': 0.0881875,
#    'val_loss': 0.48535,
#    'val_rate': 0.48535,
#    'val_mse': 0.0745503},
#   {'epoch': 3,
#    'loss': 0.479915,
#    'rate': 0.479915,
#    'mse': 0.0662015,
#    'val_loss': 0.492835,
#    'val_rate': 0.492835,
#    'val_mse': 0.0597824},
#   {'epoch': 3,
#    'loss': 0.479915,
#    'rate': 0.479915,
#    'mse': 0.0662015,
#    'val_loss': 0.492835,
#    'val_rate': 0.492835,
#    'val_mse': 0.0597824},
#   {'epoch': 4,
#    'loss': 0.397128,
#    'rate': 0.397128,
#    'mse': 0.0542505,
#    'val_loss': 0.355529,
#    'val_rate': 0.355529,
#    'val_mse': 0.0498603},
#   {'epoch': 4,
#    'loss': 0.397128,
#    'rate': 0.397128,
#    'mse': 0.0542505,
#    'val_loss': 0.355529,
#    'val_rate': 0.355529,
#    'val_mse': 0.0498603}],
#  3e-07: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 0.290977,
#    'val_loss': 0.837416,
#    'val_rate': 0.837416,
#    'val_mse': 0.089161},
#   {'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 0.290977,
#    'val_loss': 0.837416,
#    'val_rate': 0.837416,
#    'val_mse': 0.089161},
#   {'epoch': 1,
#    'loss': 0.772474,
#    'rate': 0.772474,
#    'mse': 0.0636382,
#    'val_loss': 0.645283,
#    'val_rate': 0.645283,
#    'val_mse': 0.0476926},
#   {'epoch': 1,
#    'loss': 0.772474,
#    'rate': 0.772474,
#    'mse': 0.0636382,
#    'val_loss': 0.645283,
#    'val_rate': 0.645283,
#    'val_mse': 0.0476926},
#   {'epoch': 2,
#    'loss': 0.589671,
#    'rate': 0.589671,
#    'mse': 0.040066,
#    'val_loss': 0.492284,
#    'val_rate': 0.492284,
#    'val_mse': 0.0337321},
#   {'epoch': 2,
#    'loss': 0.589671,
#    'rate': 0.589671,
#    'mse': 0.040066,
#    'val_loss': 0.492284,
#    'val_rate': 0.492284,
#    'val_mse': 0.0337321},
#   {'epoch': 3,
#    'loss': 0.479779,
#    'rate': 0.479779,
#    'mse': 0.0293991,
#    'val_loss': 0.490096,
#    'val_rate': 0.490096,
#    'val_mse': 0.0257728},
#   {'epoch': 3,
#    'loss': 0.479779,
#    'rate': 0.479779,
#    'mse': 0.0293991,
#    'val_loss': 0.490096,
#    'val_rate': 0.490096,
#    'val_mse': 0.0257728},
#   {'epoch': 4,
#    'loss': 0.397116,
#    'rate': 0.397116,
#    'mse': 0.0225105,
#    'val_loss': 0.355529,
#    'val_rate': 0.355529,
#    'val_mse': 0.0197554},
#   {'epoch': 4,
#    'loss': 0.397116,
#    'rate': 0.397116,
#    'mse': 0.0225105,
#    'val_loss': 0.355529,
#    'val_rate': 0.355529,
#    'val_mse': 0.0197554}],
#  1e-06: [{'epoch': 0,
#    'loss': 3.63899,
#    'rate': 3.63899,
#    'mse': 0.155479,
#    'val_loss': 0.837374,
#    'val_rate': 0.837374,
#    'val_mse': 0.0376711},
#   {'epoch': 0,
#    'loss': 3.63899,
#    'rate': 3.63899,
#    'mse': 0.155479,
#    'val_loss': 0.837374,
#    'val_rate': 0.837374,
#    'val_mse': 0.0376711},
#   {'epoch': 1,
#    'loss': 0.772458,
#    'rate': 0.772457,
#    'mse': 0.025138,
#    'val_loss': 0.644352,
#    'val_rate': 0.644352,
#    'val_mse': 0.0161425},
#   {'epoch': 1,
#    'loss': 0.772458,
#    'rate': 0.772457,
#    'mse': 0.025138,
#    'val_loss': 0.644352,
#    'val_rate': 0.644352,
#    'val_mse': 0.0161425},
#   {'epoch': 2,
#    'loss': 0.589414,
#    'rate': 0.589414,
#    'mse': 0.0112905,
#    'val_loss': 0.485692,
#    'val_rate': 0.485692,
#    'val_mse': 0.00764366},
#   {'epoch': 2,
#    'loss': 0.589414,
#    'rate': 0.589414,
#    'mse': 0.0112905,
#    'val_loss': 0.485692,
#    'val_rate': 0.485692,
#    'val_mse': 0.00764366},
#   {'epoch': 3,
#    'loss': 0.479892,
#    'rate': 0.479892,
#    'mse': 0.00563879,
#    'val_loss': 0.492286,
#    'val_rate': 0.492286,
#    'val_mse': 0.00415173},
#   {'epoch': 3,
#    'loss': 0.479892,
#    'rate': 0.479892,
#    'mse': 0.00563879,
#    'val_loss': 0.492286,
#    'val_rate': 0.492286,
#    'val_mse': 0.00415173},
#   {'epoch': 4,
#    'loss': 0.397131,
#    'rate': 0.397131,
#    'mse': 0.00329421,
#    'val_loss': 0.355397,
#    'val_rate': 0.355397,
#    'val_mse': 0.00263459},
#   {'epoch': 4,
#    'loss': 0.397131,
#    'rate': 0.397131,
#    'mse': 0.00329421,
#    'val_loss': 0.355397,
#    'val_rate': 0.355397,
#    'val_mse': 0.00263459}],
#  3e-06: [{'epoch': 0,
#    'loss': 3.63893,
#    'rate': 3.63893,
#    'mse': 0.0831465,
#    'val_loss': 0.837313,
#    'val_rate': 0.837313,
#    'val_mse': 0.0119243},
#   {'epoch': 0,
#    'loss': 3.63893,
#    'rate': 3.63893,
#    'mse': 0.0831465,
#    'val_loss': 0.837313,
#    'val_rate': 0.837313,
#    'val_mse': 0.0119243},
#   {'epoch': 1,
#    'loss': 0.772504,
#    'rate': 0.772504,
#    'mse': 0.00548278,
#    'val_loss': 0.644849,
#    'val_rate': 0.644849,
#    'val_mse': 0.0024133},
#   {'epoch': 1,
#    'loss': 0.772504,
#    'rate': 0.772504,
#    'mse': 0.00548278,
#    'val_loss': 0.644849,
#    'val_rate': 0.644849,
#    'val_mse': 0.0024133},
#   {'epoch': 2,
#    'loss': 0.5895,
#    'rate': 0.5895,
#    'mse': 0.00163255,
#    'val_loss': 0.487141,
#    'val_rate': 0.487141,
#    'val_mse': 0.00117237},
#   {'epoch': 2,
#    'loss': 0.5895,
#    'rate': 0.5895,
#    'mse': 0.00163255,
#    'val_loss': 0.487141,
#    'val_rate': 0.487141,
#    'val_mse': 0.00117237},
#   {'epoch': 3,
#    'loss': 0.479879,
#    'rate': 0.479879,
#    'mse': 0.000968647,
#    'val_loss': 0.486345,
#    'val_rate': 0.486345,
#    'val_mse': 0.000822816},
#   {'epoch': 3,
#    'loss': 0.479879,
#    'rate': 0.479879,
#    'mse': 0.000968647,
#    'val_loss': 0.486345,
#    'val_rate': 0.486345,
#    'val_mse': 0.000822816},
#   {'epoch': 4,
#    'loss': 0.397121,
#    'rate': 0.397121,
#    'mse': 0.000746746,
#    'val_loss': 0.355476,
#    'val_rate': 0.355476,
#    'val_mse': 0.000685569},
#   {'epoch': 4,
#    'loss': 0.397121,
#    'rate': 0.397121,
#    'mse': 0.000746746,
#    'val_loss': 0.355476,
#    'val_rate': 0.355476,
#    'val_mse': 0.000685569}],
#  1e-05: [{'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 0.0378804,
#    'val_loss': 0.837438,
#    'val_rate': 0.837438,
#    'val_mse': 0.00147806},
#   {'epoch': 0,
#    'loss': 3.63894,
#    'rate': 3.63894,
#    'mse': 0.0378804,
#    'val_loss': 0.837438,
#    'val_rate': 0.837438,
#    'val_mse': 0.00147806},
#   {'epoch': 1,
#    'loss': 0.772491,
#    'rate': 0.772491,
#    'mse': 0.000876907,
#    'val_loss': 0.643945,
#    'val_rate': 0.643945,
#    'val_mse': 0.000626826},
#   {'epoch': 1,
#    'loss': 0.772491,
#    'rate': 0.772491,
#    'mse': 0.000876907,
#    'val_loss': 0.643945,
#    'val_rate': 0.643945,
#    'val_mse': 0.000626826},
#   {'epoch': 2,
#    'loss': 0.58953,
#    'rate': 0.58953,
#    'mse': 0.00055618,
#    'val_loss': 0.487895,
#    'val_rate': 0.487895,
#    'val_mse': 0.000514126},
#   {'epoch': 2,
#    'loss': 0.58953,
#    'rate': 0.58953,
#    'mse': 0.00055618,
#    'val_loss': 0.487895,
#    'val_rate': 0.487895,
#    'val_mse': 0.000514126},
#   {'epoch': 3,
#    'loss': 0.47989,
#    'rate': 0.47989,
#    'mse': 0.00049053,
#    'val_loss': 0.487148,
#    'val_rate': 0.487148,
#    'val_mse': 0.000473681},
#   {'epoch': 3,
#    'loss': 0.47989,
#    'rate': 0.47989,
#    'mse': 0.00049053,
#    'val_loss': 0.487148,
#    'val_rate': 0.487148,
#    'val_mse': 0.000473681},
#   {'epoch': 4,
#    'loss': 0.397133,
#    'rate': 0.397133,
#    'mse': 0.000464205,
#    'val_loss': 0.35534,
#    'val_rate': 0.35534,
#    'val_mse': 0.00045706},
#   {'epoch': 4,
#    'loss': 0.397133,
#    'rate': 0.397133,
#    'mse': 0.000464205,
#    'val_loss': 0.35534,
#    'val_rate': 0.35534,
#    'val_mse': 0.00045706}],
#  3e-05: [{'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 0.0180468,
#    'val_loss': 0.837582,
#    'val_rate': 0.837582,
#    'val_mse': 0.000569781},
#   {'epoch': 0,
#    'loss': 3.63893,
#    'rate': 3.63893,
#    'mse': 0.0180468,
#    'val_loss': 0.837549,
#    'val_rate': 0.837549,
#    'val_mse': 0.000569774},
#   {'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 0.0180468,
#    'val_loss': 0.837582,
#    'val_rate': 0.837582,
#    'val_mse': 0.000569781},
#   {'epoch': 0,
#    'loss': 3.63893,
#    'rate': 3.63893,
#    'mse': 0.0180468,
#    'val_loss': 0.837549,
#    'val_rate': 0.837549,
#    'val_mse': 0.000569774},
#   {'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 0.0180468,
#    'val_loss': 0.837582,
#    'val_rate': 0.837582,
#    'val_mse': 0.000569781},
#   {'epoch': 0,
#    'loss': 3.63893,
#    'rate': 3.63893,
#    'mse': 0.0180468,
#    'val_loss': 0.837549,
#    'val_rate': 0.837549,
#    'val_mse': 0.000569774},
#   {'epoch': 1,
#    'loss': 0.772463,
#    'rate': 0.772463,
#    'mse': 0.000491227,
#    'val_loss': 0.644808,
#    'val_rate': 0.644808,
#    'val_mse': 0.000455206},
#   {'epoch': 1,
#    'loss': 0.772488,
#    'rate': 0.772488,
#    'mse': 0.000491227,
#    'val_loss': 0.645232,
#    'val_rate': 0.645232,
#    'val_mse': 0.000455214},
#   {'epoch': 1,
#    'loss': 0.772463,
#    'rate': 0.772463,
#    'mse': 0.000491227,
#    'val_loss': 0.644808,
#    'val_rate': 0.644808,
#    'val_mse': 0.000455206},
#   {'epoch': 1,
#    'loss': 0.772488,
#    'rate': 0.772488,
#    'mse': 0.000491227,
#    'val_loss': 0.645232,
#    'val_rate': 0.645232,
#    'val_mse': 0.000455214}],
#  0.0001: [{'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 0.00822445,
#    'val_loss': 0.837444,
#    'val_rate': 0.837444,
#    'val_mse': 0.000441118},
#   {'epoch': 0,
#    'loss': 3.63897,
#    'rate': 3.63897,
#    'mse': 0.00822445,
#    'val_loss': 0.837444,
#    'val_rate': 0.837444,
#    'val_mse': 0.000441118},
#   {'epoch': 1,
#    'loss': 0.772459,
#    'rate': 0.772459,
#    'mse': 0.000426937,
#    'val_loss': 0.644861,
#    'val_rate': 0.644861,
#    'val_mse': 0.000420923},
#   {'epoch': 1,
#    'loss': 0.772459,
#    'rate': 0.772459,
#    'mse': 0.000426937,
#    'val_loss': 0.644861,
#    'val_rate': 0.644861,
#    'val_mse': 0.000420923},
#   {'epoch': 2,
#    'loss': 0.589528,
#    'rate': 0.589527,
#    'mse': 0.000417373,
#    'val_loss': 0.4886,
#    'val_rate': 0.488599,
#    'val_mse': 0.000416536},
#   {'epoch': 2,
#    'loss': 0.589528,
#    'rate': 0.589527,
#    'mse': 0.000417373,
#    'val_loss': 0.4886,
#    'val_rate': 0.488599,
#    'val_mse': 0.000416536},
#   {'epoch': 3,
#    'loss': 0.479865,
#    'rate': 0.479864,
#    'mse': 0.000414609,
#    'val_loss': 0.490643,
#    'val_rate': 0.490643,
#    'val_mse': 0.000414547},
#   {'epoch': 3,
#    'loss': 0.479865,
#    'rate': 0.479864,
#    'mse': 0.000414609,
#    'val_loss': 0.490643,
#    'val_rate': 0.490643,
#    'val_mse': 0.000414547},
#   {'epoch': 4,
#    'loss': 0.397132,
#    'rate': 0.397131,
#    'mse': 0.00041333,
#    'val_loss': 0.3556,
#    'val_rate': 0.3556,
#    'val_mse': 0.000413769},
#   {'epoch': 4,
#    'loss': 0.397132,
#    'rate': 0.397131,
#    'mse': 0.00041333,
#    'val_loss': 0.3556,
#    'val_rate': 0.3556,
#    'val_mse': 0.000413769}],
#  0.0003: [{'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 0.00421479,
#    'val_loss': 0.837479,
#    'val_rate': 0.837479,
#    'val_mse': 0.000418869},
#   {'epoch': 0,
#    'loss': 3.63895,
#    'rate': 3.63895,
#    'mse': 0.00421479,
#    'val_loss': 0.837479,
#    'val_rate': 0.837479,
#    'val_mse': 0.000418869},
#   {'epoch': 1,
#    'loss': 0.772498,
#    'rate': 0.772498,
#    'mse': 0.000414655,
#    'val_loss': 0.644128,
#    'val_rate': 0.644127,
#    'val_mse': 0.000413711},
#   {'epoch': 1,
#    'loss': 0.772498,
#    'rate': 0.772498,
#    'mse': 0.000414655,
#    'val_loss': 0.644128,
#    'val_rate': 0.644127,
#    'val_mse': 0.000413711},
#   {'epoch': 2,
#    'loss': 0.589411,
#    'rate': 0.589411,
#    'mse': 0.00041212,
#    'val_loss': 0.485583,
#    'val_rate': 0.485583,
#    'val_mse': 0.00041251},
#   {'epoch': 2,
#    'loss': 0.589411,
#    'rate': 0.589411,
#    'mse': 0.00041212,
#    'val_loss': 0.485583,
#    'val_rate': 0.485583,
#    'val_mse': 0.00041251},
#   {'epoch': 3,
#    'loss': 0.479924,
#    'rate': 0.479924,
#    'mse': 0.000411368,
#    'val_loss': 0.48954,
#    'val_rate': 0.48954,
#    'val_mse': 0.000411957},
#   {'epoch': 3,
#    'loss': 0.479924,
#    'rate': 0.479924,
#    'mse': 0.000411368,
#    'val_loss': 0.48954,
#    'val_rate': 0.48954,
#    'val_mse': 0.000411957},
#   {'epoch': 4,
#    'loss': 0.39715,
#    'rate': 0.39715,
#    'mse': 0.000411014,
#    'val_loss': 0.355448,
#    'val_rate': 0.355448,
#    'val_mse': 0.000411749},
#   {'epoch': 4,
#    'loss': 0.39715,
#    'rate': 0.39715,
#    'mse': 0.000411014,
#    'val_loss': 0.355448,
#    'val_rate': 0.355448,
#    'val_mse': 0.000411749}],
#  0.001: [{'epoch': 0,
#    'loss': 3.63896,
#    'rate': 3.63896,
#    'mse': 0.0022832,
#    'val_loss': 0.837383,
#    'val_rate': 0.837383,
#    'val_mse': 0.000413006},
#   {'epoch': 0,
#    'loss': 3.63896,
#    'rate': 3.63896,
#    'mse': 0.0022832,
#    'val_loss': 0.837383,
#    'val_rate': 0.837383,
#    'val_mse': 0.000413006},
#   {'epoch': 1,
#    'loss': 0.772456,
#    'rate': 0.772456,
#    'mse': 0.000411294,
#    'val_loss': 0.645277,
#    'val_rate': 0.645277,
#    'val_mse': 0.000411682},
#   {'epoch': 1,
#    'loss': 0.772456,
#    'rate': 0.772456,
#    'mse': 0.000411294,
#    'val_loss': 0.645277,
#    'val_rate': 0.645277,
#    'val_mse': 0.000411682},
#   {'epoch': 2,
#    'loss': 0.58955,
#    'rate': 0.58955,
#    'mse': 0.000410635,
#    'val_loss': 0.488215,
#    'val_rate': 0.488215,
#    'val_mse': 0.000411367},
#   {'epoch': 2,
#    'loss': 0.58955,
#    'rate': 0.58955,
#    'mse': 0.000410635,
#    'val_loss': 0.488215,
#    'val_rate': 0.488215,
#    'val_mse': 0.000411367},
#   {'epoch': 3,
#    'loss': 0.479889,
#    'rate': 0.479889,
#    'mse': 0.000410441,
#    'val_loss': 0.486728,
#    'val_rate': 0.486728,
#    'val_mse': 0.000411218},
#   {'epoch': 3,
#    'loss': 0.479889,
#    'rate': 0.479889,
#    'mse': 0.000410441,
#    'val_loss': 0.486728,
#    'val_rate': 0.486728,
#    'val_mse': 0.000411218},
#   {'epoch': 4,
#    'loss': 0.397086,
#    'rate': 0.397086,
#    'mse': 0.000410345,
#    'val_loss': 0.355827,
#    'val_rate': 0.355826,
#    'val_mse': 0.000411164},
#   {'epoch': 4,
#    'loss': 0.397086,
#    'rate': 0.397086,
#    'mse': 0.000410345,
#    'val_loss': 0.355827,
#    'val_rate': 0.355826,
#    'val_mse': 0.000411164}],
#  0.003: [{'epoch': 0,
#    'loss': 3.63896,
#    'rate': 3.63896,
#    'mse': 0.00155377,
#    'val_loss': 0.837389,
#    'val_rate': 0.837388,
#    'val_mse': 0.000411633},
#   {'epoch': 0,
#    'loss': 3.63896,
#    'rate': 3.63896,
#    'mse': 0.00155377,
#    'val_loss': 0.837389,
#    'val_rate': 0.837388,
#    'val_mse': 0.000411633},
#   {'epoch': 1,
#    'loss': 0.772456,
#    'rate': 0.772455,
#    'mse': 0.000410499,
#    'val_loss': 0.645538,
#    'val_rate': 0.645537,
#    'val_mse': 0.000411195},
#   {'epoch': 1,
#    'loss': 0.772456,
#    'rate': 0.772455,
#    'mse': 0.000410499,
#    'val_loss': 0.645538,
#    'val_rate': 0.645537,
#    'val_mse': 0.000411195},
#   {'epoch': 2,
#    'loss': 0.589532,
#    'rate': 0.589531,
#    'mse': 0.000410279,
#    'val_loss': 0.48891,
#    'val_rate': 0.488909,
#    'val_mse': 0.00041109},
#   {'epoch': 2,
#    'loss': 0.589532,
#    'rate': 0.589531,
#    'mse': 0.000410279,
#    'val_loss': 0.48891,
#    'val_rate': 0.488909,
#    'val_mse': 0.00041109},
#   {'epoch': 3,
#    'loss': 0.479863,
#    'rate': 0.479862,
#    'mse': 0.000410217,
#    'val_loss': 0.489037,
#    'val_rate': 0.489035,
#    'val_mse': 0.00041104},
#   {'epoch': 3,
#    'loss': 0.479863,
#    'rate': 0.479862,
#    'mse': 0.000410217,
#    'val_loss': 0.489037,
#    'val_rate': 0.489035,
#    'val_mse': 0.00041104},
#   {'epoch': 4,
#    'loss': 0.39711,
#    'rate': 0.397109,
#    'mse': 0.000410183,
#    'val_loss': 0.3556,
#    'val_rate': 0.355599,
#    'val_mse': 0.000411023},
#   {'epoch': 4,
#    'loss': 0.39711,
#    'rate': 0.397109,
#    'mse': 0.000410183,
#    'val_loss': 0.3556,
#    'val_rate': 0.355599,
#    'val_mse': 0.000411023}],
#  0.01: [],
#  0.03: [{'epoch': 0,
#    'loss': 3.63898,
#    'rate': 3.63894,
#    'mse': 0.00109973,
#    'val_loss': 0.837351,
#    'val_rate': 0.837338,
#    'val_mse': 0.000410979},
#   {'epoch': 0,
#    'loss': 3.63898,
#    'rate': 3.63894,
#    'mse': 0.00109973,
#    'val_loss': 0.837351,
#    'val_rate': 0.837338,
#    'val_mse': 0.000410979},
#   {'epoch': 1,
#    'loss': 0.772489,
#    'rate': 0.772477,
#    'mse': 0.000410127,
#    'val_loss': 0.645818,
#    'val_rate': 0.645805,
#    'val_mse': 0.000410979},
#   {'epoch': 1,
#    'loss': 0.772489,
#    'rate': 0.772477,
#    'mse': 0.000410127,
#    'val_loss': 0.645818,
#    'val_rate': 0.645805,
#    'val_mse': 0.000410979},
#   {'epoch': 2,
#    'loss': 0.589451,
#    'rate': 0.58944,
#    'mse': 0.00041013,
#    'val_loss': 0.485413,
#    'val_rate': 0.485401,
#    'val_mse': 0.000410982},
#   {'epoch': 2,
#    'loss': 0.589451,
#    'rate': 0.58944,
#    'mse': 0.00041013,
#    'val_loss': 0.485413,
#    'val_rate': 0.485401,
#    'val_mse': 0.000410982},
#   {'epoch': 3,
#    'loss': 0.479933,
#    'rate': 0.479921,
#    'mse': 0.000410135,
#    'val_loss': 0.492365,
#    'val_rate': 0.492352,
#    'val_mse': 0.000410986},
#   {'epoch': 3,
#    'loss': 0.479933,
#    'rate': 0.479921,
#    'mse': 0.000410135,
#    'val_loss': 0.492365,
#    'val_rate': 0.492352,
#    'val_mse': 0.000410986},
#   {'epoch': 4,
#    'loss': 0.39713,
#    'rate': 0.397118,
#    'mse': 0.000410133,
#    'val_loss': 0.355818,
#    'val_rate': 0.355806,
#    'val_mse': 0.000410985},
#   {'epoch': 4,
#    'loss': 0.39713,
#    'rate': 0.397118,
#    'mse': 0.000410133,
#    'val_loss': 0.355818,
#    'val_rate': 0.355806,
#    'val_mse': 0.000410985}],
#  0.1: [{'epoch': 0,
#    'loss': 3.63906,
#    'rate': 3.63896,
#    'mse': 0.00104805,
#    'val_loss': 0.837524,
#    'val_rate': 0.837483,
#    'val_mse': 0.000410968},
#   {'epoch': 0,
#    'loss': 3.63906,
#    'rate': 3.63896,
#    'mse': 0.00104805,
#    'val_loss': 0.837524,
#    'val_rate': 0.837483,
#    'val_mse': 0.000410968},
#   {'epoch': 1,
#    'loss': 0.772518,
#    'rate': 0.772478,
#    'mse': 0.000410121,
#    'val_loss': 0.644359,
#    'val_rate': 0.644318,
#    'val_mse': 0.000410978},
#   {'epoch': 1,
#    'loss': 0.772518,
#    'rate': 0.772478,
#    'mse': 0.000410121,
#    'val_loss': 0.644359,
#    'val_rate': 0.644318,
#    'val_mse': 0.000410978},
#   {'epoch': 2,
#    'loss': 0.589542,
#    'rate': 0.589502,
#    'mse': 0.000410134,
#    'val_loss': 0.487957,
#    'val_rate': 0.487916,
#    'val_mse': 0.000410991},
#   {'epoch': 2,
#    'loss': 0.589542,
#    'rate': 0.589502,
#    'mse': 0.000410134,
#    'val_loss': 0.487957,
#    'val_rate': 0.487916,
#    'val_mse': 0.000410991},
#   {'epoch': 3,
#    'loss': 0.479882,
#    'rate': 0.47984,
#    'mse': 0.000410151,
#    'val_loss': 0.488934,
#    'val_rate': 0.488892,
#    'val_mse': 0.000411008},
#   {'epoch': 3,
#    'loss': 0.479882,
#    'rate': 0.47984,
#    'mse': 0.000410151,
#    'val_loss': 0.488934,
#    'val_rate': 0.488892,
#    'val_mse': 0.000411008},
#   {'epoch': 4,
#    'loss': 0.397137,
#    'rate': 0.397095,
#    'mse': 0.000410158,
#    'val_loss': 0.355895,
#    'val_rate': 0.355854,
#    'val_mse': 0.000411017},
#   {'epoch': 4,
#    'loss': 0.397137,
#    'rate': 0.397095,
#    'mse': 0.000410158,
#    'val_loss': 0.355895,
#    'val_rate': 0.355854,
#    'val_mse': 0.000411017}],
#  0.3: [],
#  1.0: [],
#  3.0: [],
#  10.0: [],
#  30.0: [],
#  100.0: [],
#  300.0: [],
#  1000.0: []}
